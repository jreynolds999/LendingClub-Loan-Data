# %% [markdown]
# # Predicting Bad Loans with Machine Learning - Part 1: EDA

# %% [markdown]
# ### Content List
# #### Imports
# #### Loading the Data
# #### Defining Target Feature

# %% [markdown]
# Preliminary EDA Steps:
# - Identify the data types you are working with.
# - Examine the distributions of your data, numerically and/or visually.
# - Identify outliers.
# - Identify missing data and look for patterns of missing data.
# - Describe how your EDA will inform your modeling decisions and process.

# %% [markdown]
# ### Imports
# Standard imports, drawing heavily from pandas for data munging, whereas seaborn, folium and matplotlib were for visualizations.

# %%
### Imports
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import math
import folium
from datetime import datetime

# %% [markdown]
# #### Reading in Data from CSV
# This data comes from a Kaggle dataset initially, from this link: https://www.kaggle.com/wordsforthewise/lending-club. At the onset of this project I considered utilizing the Lending Club API, but found it segmented into quarterly data which created an additional layer of data munging. Due to the inherent time constraint on the first run of this project, I opted out of interacting directly with Lending Club and chose to instead use the aforementioned link which had already aggregated the information into a single file. The author was kind enough to perform some data cleaning of their own as they "cleaned the data a tiny bit: I removed percent symbols (%) from int_rate and revol_util columns in the accepted loans and converted those columns to floats."

# %%
#read in file from csv to dataframe
data_read = pd.read_csv('./accepted_2007_to_2018Q4.csv')
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (0,19,49,59,118,129,130,131,134,135,136,139,145,146,147) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
for i in data_read.columns:
    print(i)
# Out:
# id
# member_id
# loan_amnt
# funded_amnt
# funded_amnt_inv
# term
# int_rate
# installment
# grade
# sub_grade
# emp_title
# emp_length
# home_ownership
# annual_inc
# verification_status
# issue_d
# loan_status
# pymnt_plan
# url
# desc
# purpose
# title
# zip_code
# addr_state
# dti
# delinq_2yrs
# earliest_cr_line
# fico_range_low
# fico_range_high
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# initial_list_status
# out_prncp
# out_prncp_inv
# total_pymnt
# total_pymnt_inv
# total_rec_prncp
# total_rec_int
# total_rec_late_fee
# recoveries
# collection_recovery_fee
# last_pymnt_d
# last_pymnt_amnt
# next_pymnt_d
# last_credit_pull_d
# last_fico_range_high
# last_fico_range_low
# collections_12_mths_ex_med
# mths_since_last_major_derog
# policy_code
# application_type
# annual_inc_joint
# dti_joint
# verification_status_joint
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_act_il
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
# revol_bal_joint
# sec_app_fico_range_low
# sec_app_fico_range_high
# sec_app_earliest_cr_line
# sec_app_inq_last_6mths
# sec_app_mort_acc
# sec_app_open_acc
# sec_app_revol_util
# sec_app_open_act_il
# sec_app_num_rev_accts
# sec_app_chargeoff_within_12_mths
# sec_app_collections_12_mths_ex_med
# sec_app_mths_since_last_major_derog
# hardship_flag
# hardship_type
# hardship_reason
# hardship_status
# deferral_term
# hardship_amount
# hardship_start_date
# hardship_end_date
# payment_plan_start_date
# hardship_length
# hardship_dpd
# hardship_loan_status
# orig_projected_additional_accrued_interest
# hardship_payoff_balance_amount
# hardship_last_payment_amount
# disbursement_method
# debt_settlement_flag
# debt_settlement_flag_date
# settlement_status
# settlement_date
# settlement_amount
# settlement_percentage
# settlement_term

# %%
print(f'There are a total of {len(data_read.columns)} columns by default.')
# Out:
# There are a total of 151 columns by default.

# %%
# By saving the data as something other than what was imported, I no longer need to read in the data again to reset
data = data_read

# %%
data.shape
# Out:
# (2260701, 151)

# %% [markdown]
# **Findings:** This is by far the largest data set I will have ever worked with, as there are over 2.25 MILLION rows, and 145 columns for a total of more than 3 BILLION values. I will be reducing the dataset as I continue my EDA process, but will make sure to retain as much of the potential value and representation of the dataset as possible. Additionally, I see the trajectory of data collection over time through my outside research. There is a marked differences in dataset size over time: in 2014 there were only 188,127 rows and 31 features, whereas there are now 2,260,701 rows and 151 features. This represents an increase of approximately 58.5x over the course of 3 years and speaks as to the accelerating speed of data creation.

# %%
### Identifying contents of data( data types, shape, descriptive statistics, etc)
missing_data = data.isna()
missing_data_amount = missing_data.sum().sum()
print(f'There are {missing_data_amount} missing values in the Lending Club dataset.')
# Out:
# There are 108486249 missing values in the Lending Club dataset.

# %%
data.dtypes.value_counts(normalize=True)
# Out:
# float64    0.748344
# object     0.251656
# dtype: float64

# %% [markdown]
# The object types are not overly complex as the split is approximately 75% Float64 and 25% Object. Since Machine Learning requires numeric inputs in order to function, it is a relief that there is not an overwhelming amount of Object (or any other non-numeric) data types for our 151 features.

# %%
data.describe()
# Out:
#        member_id     loan_amnt   funded_amnt  funded_amnt_inv      int_rate  \
# count        0.0  2.260668e+06  2.260668e+06     2.260668e+06  2.260668e+06
# mean         NaN  1.504693e+04  1.504166e+04     1.502344e+04  1.309283e+01
# std          NaN  9.190245e+03  9.188413e+03     9.192332e+03  4.832138e+00
# min          NaN  5.000000e+02  5.000000e+02     0.000000e+00  5.310000e+00
# 25%          NaN  8.000000e+03  8.000000e+03     8.000000e+03  9.490000e+00
# 50%          NaN  1.290000e+04  1.287500e+04     1.280000e+04  1.262000e+01
# 75%          NaN  2.000000e+04  2.000000e+04     2.000000e+04  1.599000e+01
# max          NaN  4.000000e+04  4.000000e+04     4.000000e+04  3.099000e+01
#
#         installment    annual_inc           dti   delinq_2yrs  fico_range_low  \
# count  2.260668e+06  2.260664e+06  2.258957e+06  2.260639e+06    2.260668e+06
# mean   4.458068e+02  7.799243e+04  1.882420e+01  3.068792e-01    6.985882e+02
# std    2.671735e+02  1.126962e+05  1.418333e+01  8.672303e-01    3.301038e+01
# min    4.930000e+00  0.000000e+00 -1.000000e+00  0.000000e+00    6.100000e+02
# 25%    2.516500e+02  4.600000e+04  1.189000e+01  0.000000e+00    6.750000e+02
# 50%    3.779900e+02  6.500000e+04  1.784000e+01  0.000000e+00    6.900000e+02
# 75%    5.933200e+02  9.300000e+04  2.449000e+01  0.000000e+00    7.150000e+02
# max    1.719830e+03  1.100000e+08  9.990000e+02  5.800000e+01    8.450000e+02
#
#        ...  deferral_term  hardship_amount  hardship_length  hardship_dpd  \
# count  ...        10917.0     10917.000000          10917.0  10917.000000
# mean   ...            3.0       155.045981              3.0     13.743886
# std    ...            0.0       129.040594              0.0      9.671178
# min    ...            3.0         0.640000              3.0      0.000000
# 25%    ...            3.0        59.440000              3.0      5.000000
# 50%    ...            3.0       119.140000              3.0     15.000000
# 75%    ...            3.0       213.260000              3.0     22.000000
# max    ...            3.0       943.940000              3.0     37.000000
#
#        orig_projected_additional_accrued_interest  \
# count                                 8651.000000
# mean                                   454.798089
# std                                    375.385500
# min                                      1.920000
# 25%                                    175.230000
# 50%                                    352.770000
# 75%                                    620.175000
# max                                   2680.890000
#
#        hardship_payoff_balance_amount  hardship_last_payment_amount  \
# count                    10917.000000                  10917.000000
# mean                     11636.883942                    193.994321
# std                       7625.988281                    198.629496
# min                         55.730000                      0.010000
# 25%                       5627.000000                     44.440000
# 50%                      10028.390000                    133.160000
# 75%                      16151.890000                    284.190000
# max                      40306.410000                   1407.860000
#
#        settlement_amount  settlement_percentage  settlement_term
# count       34246.000000           34246.000000     34246.000000
# mean         5010.664267              47.780365        13.191322
# std          3693.122590               7.311822         8.159980
# min            44.210000               0.200000         0.000000
# 25%          2208.000000              45.000000         6.000000
# 50%          4146.110000              45.000000        14.000000
# 75%          6850.172500              50.000000        18.000000
# max         33601.000000             521.350000       181.000000
#
# [8 rows x 113 columns]

# %% [markdown]
# **FINDINGS:** From the describe method, we can already verify there are multiple columns with many missing values. There are outliers present as well, specifically in annual_inc (Reported Annual Income). These will have to be dealt with before modeling. We can go ahead and immediately drop the id, member_id and url columns as they contain no information (useful or otherwise), verified by consulting the data dictionary. We can also see that there are individuals who have reported 0 annual income, which may be important moving forward merit further investigation.

# %% [markdown]
# ## Defining Target Feature:
# . Defining our target feature is a key element of the data science process, as our ability to generate successful predictions depends on how well we can define success and failure- commonly referenced as 1 and 0, respectively. Prior to beginning the EDA, I made sure to read at least a handful of prior approaches to the question of how to differentiate Good from Bad loans. The definition of the Target Feature split the prior work almost evenly over the question of whether to involve the "Current" loans in the Success, or 1, class. After reading through the commentary provided by the authors, I choose to eliminate the "Current" loans from the dataset entirely as there is uncertainty as to whether they will end up being successes or failures. If I included the "Current" and "In Grace Period" loans as others did- such as XXX et al did- then my model would suffer from a systematic increase in the risk of labeling True Negatives as Positive, resulting in False Positives. This would result in a two-fold loss on the part of the investors: firstly from their principal investment and secondly from the lost income from the interest payments. Therefore, I drop "Current" and combine the 'Fully Paid' sections into 1 from the 'loan_status' column. By combining remaining columns into 0, I define the Failure class for my machine learning model.

# %%
data['loan_status'].value_counts(normalize=True)
# Out:
# Fully Paid                                             0.476298
# Current                                                0.388521
# Charged Off                                            0.118796
# Late (31-120 days)                                     0.009496
# In Grace Period                                        0.003732
# Late (16-30 days)                                      0.001924
# Does not meet the credit policy. Status:Fully Paid     0.000879
# Does not meet the credit policy. Status:Charged Off    0.000337
# Default                                                0.000018
# Name: loan_status, dtype: float64

# %% [markdown]
# **Thoughts:** One interesting finding is that there is a drastically lower Default percentage than I assumed. This is most likely due to the prevalence of restructuring loans, in order to pad the numbers of Lending Club and present the best foot forward for potential investors- in both the loans themselves and the company's stock. The fact that 'Current' and 'In Grace Period' account for more than 40% of the data is unfortunate, but for the reasons discussed before it is necessary to remove them. The remaining amount of data, approximately 900,000 loans, is more than enough for our needs so it is not a large concern.

# %%
#applying the class definitions to the columns
data = data.dropna(subset=['loan_status'])

#using masking to exclude all loans that include 'Current' and 'In Grace Period' text in the fields
data = data[data['loan_status'] != 'Current']
data = data[data['loan_status'] != 'In Grace Period']

#after dropping 'Current' and 'In Grace Period' the lambda function makes the rest of it easy!
data['classes'] = data['loan_status'].apply(lambda x: 1 if 'Fully Paid' in x else 0)

# %%
data['classes'].value_counts(normalize=True)
# Out:
# 1    0.785157
# 0    0.214843
# Name: classes, dtype: float64

# %% [markdown]
# After performing the feature engineering for the classes, it is apparent that the classes are imbalanced. I will have to normalize them in order to get a better predictive capacity for Accuracy or I can use other metrics to determine model quality.

# %% [markdown]
# ### Dropping specific columns to improve processing and speed
# This dataset is exceedingly large for my computer, so as a precaution I will be dropping columns that have no
# - drop data['loan_status']
# - id, member_id, url as they contain no information
# - all hardship columns (there is a binary flag existing)
# - all secondary applicant columns (using just the application_type to signify whether it was joint or single)
# - all settlement info (as this is redundant info- if the loan wasnt paid off entirely they will be in settlement)
# - all columns that have more than 70% missing values

# %%
data.isnull().sum()
# Out:
# id                                                  0
# member_id                                     1373915
# loan_amnt                                           0
# funded_amnt                                         0
# funded_amnt_inv                                     0
# term                                                0
# int_rate                                            0
# installment                                         0
# grade                                               0
# sub_grade                                           0
# emp_title                                       88473
# emp_length                                      80850
# home_ownership                                      0
# annual_inc                                          4
# verification_status                                 0
# issue_d                                             0
# loan_status                                         0
# pymnt_plan                                          0
# url                                                 0
# desc                                          1247945
# purpose                                             0
# title                                           17008
# zip_code                                            1
# addr_state                                          0
# dti                                               403
# delinq_2yrs                                        29
# earliest_cr_line                                   29
# fico_range_low                                      0
# fico_range_high                                     0
# inq_last_6mths                                     30
#                                                ...
# sec_app_revol_util                            1353192
# sec_app_open_act_il                           1352813
# sec_app_num_rev_accts                         1352813
# sec_app_chargeoff_within_12_mths              1352813
# sec_app_collections_12_mths_ex_med            1352813
# sec_app_mths_since_last_major_derog           1366248
# hardship_flag                                       0
# hardship_type                                 1366284
# hardship_reason                               1366284
# hardship_status                               1366284
# deferral_term                                 1366284
# hardship_amount                               1366284
# hardship_start_date                           1366284
# hardship_end_date                             1366284
# payment_plan_start_date                       1366284
# hardship_length                               1366284
# hardship_dpd                                  1366284
# hardship_loan_status                          1366284
# orig_projected_additional_accrued_interest    1368464
# hardship_payoff_balance_amount                1366284
# hardship_last_payment_amount                  1366284
# disbursement_method                                 0
# debt_settlement_flag                                0
# debt_settlement_flag_date                     1339707
# settlement_status                             1339707
# settlement_date                               1339707
# settlement_amount                             1339707
# settlement_percentage                         1339707
# settlement_term                               1339707
# classes                                             0
# Length: 152, dtype: int64

# %%
data = data.drop(columns= ['id', 'member_id', 'url', 'policy_code'])

# %%
### Zip code information is not feasible for the timeframe of the project due to lack of full zip codes provided
data['zip_code'].head()
# Out:
# 0    190xx
# 1    577xx
# 2    605xx
# 4    174xx
# 5    300xx
# Name: zip_code, dtype: object

# %%
data = data.drop(columns=['loan_status'])

# %%
data = data.drop(columns=['zip_code','sub_grade','mths_since_last_record','mths_since_last_delinq', 'mths_since_recent_bc_dlq','mths_since_recent_bc',
                          'mths_since_recent_inq', 'mths_since_recent_revol_delinq', 'mo_sin_old_il_acct',
                          'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl', 'last_credit_pull_d'])

# %%
data = data.drop(columns=['last_pymnt_d', 'next_pymnt_d','total_bal_il', 'total_bc_limit', 'total_cu_tl',
                          'total_pymnt', 'total_pymnt_inv', 'total_rec_int',
                          'total_rec_late_fee', 'total_rec_prncp', 'total_rev_hi_lim', 'initial_list_status'])

# %%
# All of the hardship data has been reduced to whether or not there was a payment plan present
data = data.drop(columns=['debt_settlement_flag_date', 'hardship_type',
                          'hardship_reason', 'hardship_status', 
                          'hardship_amount', 'hardship_start_date',
                          'hardship_end_date', 'payment_plan_start_date', 'hardship_length',
                          'hardship_dpd', 'hardship_loan_status', 'deferral_term',
                          'orig_projected_additional_accrued_interest',
                          'hardship_payoff_balance_amount', 'hardship_last_payment_amount'])

# %%
# all of these features are reduced to the 'application_type' which binarizes between single and joint applicant

data = data.drop(columns=['sec_app_earliest_cr_line',
                          'revol_bal_joint','verification_status_joint', 'dti_joint', 'annual_inc_joint',
                          'sec_app_inq_last_6mths', 'sec_app_mort_acc',
                          'sec_app_open_acc', 'sec_app_revol_util','sec_app_open_act_il',
                          'sec_app_num_rev_accts', 'sec_app_chargeoff_within_12_mths',
                          'sec_app_collections_12_mths_ex_med', 'sec_app_mths_since_last_major_derog', 'sec_app_fico_range_low', 'sec_app_fico_range_high' ])

# %%
data = data.drop(columns=['all_util', 'open_acc_6m', 'inq_last_12m', 'open_act_il', 
                          'open_il_12m', 'open_il_24m', 'open_rv_12m', 'open_rv_24m', 
                          'inq_fi', 'max_bal_bc', 'mths_since_last_major_derog',
                          'il_util', 'num_tl_120dpd_2m', 'mths_since_rcnt_il'])

# %%
#similar to prior groupings, one feature 'settlement_flag' represents these features in order to reduce complexity
data= data.drop(columns=['settlement_status', 'settlement_date',
                         'settlement_amount', 'settlement_percentage', 'settlement_term'])

# %% [markdown]
# ## Important to check correlations between features to avoid colinearity- AUTOMATE VIA CODE

# %%
corr_df = data.corr()

corr_df
# Out:
#                             loan_amnt  funded_amnt  funded_amnt_inv  int_rate  \
# loan_amnt                    1.000000     0.999556         0.998259  0.142477
# funded_amnt                  0.999556     1.000000         0.998808  0.142571
# funded_amnt_inv              0.998259     0.998808         1.000000  0.142661
# int_rate                     0.142477     0.142571         0.142661  1.000000
# installment                  0.953021     0.953674         0.952313  0.155666
# annual_inc                   0.309873     0.309765         0.309242 -0.071362
# dti                          0.032195     0.032588         0.033657  0.146165
# delinq_2yrs                 -0.002138    -0.001945        -0.001645  0.047965
# fico_range_low               0.101643     0.100813         0.100030 -0.403169
# fico_range_high              0.101642     0.100812         0.100029 -0.403166
# inq_last_6mths              -0.019264    -0.019645        -0.022477  0.209321
# open_acc                     0.185681     0.185981         0.186387 -0.004353
# pub_rec                     -0.064388    -0.064146        -0.063475  0.052233
# revol_bal                    0.314501     0.314379         0.313296 -0.028264
# revol_util                   0.106218     0.106383         0.106490  0.240323
# total_acc                    0.207573     0.207506         0.207591 -0.043344
# out_prncp                    0.109561     0.109717         0.109926  0.070006
# out_prncp_inv                0.109561     0.109717         0.109927  0.070007
# recoveries                   0.187639     0.187775         0.187526  0.184337
# collection_recovery_fee      0.179745     0.179954         0.179623  0.171063
# last_pymnt_amnt              0.492016     0.492400         0.492682  0.079604
# last_fico_range_high         0.048651     0.048420         0.048267 -0.348143
# last_fico_range_low          0.046008     0.045824         0.045783 -0.270077
# collections_12_mths_ex_med  -0.017797    -0.017690        -0.017403  0.015452
# acc_now_delinq               0.001500     0.001566         0.001684  0.016639
# tot_coll_amt                -0.003434    -0.003434        -0.003434  0.002360
# tot_cur_bal                  0.313727     0.313727         0.313750 -0.084877
# acc_open_past_24mths         0.009901     0.009902         0.009893  0.189125
# avg_cur_bal                  0.228813     0.228814         0.228835 -0.084062
# bc_open_to_buy               0.198490     0.198497         0.198552 -0.279467
# bc_util                      0.051034     0.051028         0.050967  0.250880
# chargeoff_within_12_mths    -0.000613    -0.000532        -0.000344  0.011634
# delinq_amnt                  0.000454     0.000473         0.000509  0.005333
# mort_acc                     0.222444     0.222446         0.222459 -0.084655
# num_accts_ever_120_pd       -0.049895    -0.049897        -0.049914  0.043085
# num_actv_bc_tl               0.194419     0.194419         0.194401  0.022400
# num_actv_rev_tl              0.151521     0.151520         0.151492  0.085249
# num_bc_sats                  0.214004     0.214003         0.214002 -0.054187
# num_bc_tl                    0.196046     0.196045         0.196028 -0.084845
# num_il_tl                    0.077918     0.077917         0.077913  0.011222
# num_op_rev_tl                0.165899     0.165898         0.165888 -0.009371
# num_rev_accts                0.169400     0.169398         0.169385 -0.057986
# num_rev_tl_bal_gt_0          0.150833     0.150833         0.150803  0.085073
# num_sats                     0.182377     0.182377         0.182369 -0.009847
# num_tl_30dpd                 0.002409     0.002409         0.002397  0.013722
# num_tl_90g_dpd_24m          -0.021811    -0.021812        -0.021826  0.026583
# num_tl_op_past_12m          -0.020131    -0.020133        -0.020149  0.206641
# pct_tl_nvr_dlq               0.087934     0.087934         0.087948 -0.063701
# percent_bc_gt_75             0.020342     0.020341         0.020290  0.248037
# pub_rec_bankruptcies        -0.092956    -0.092761        -0.092393  0.058580
# tax_liens                    0.007817     0.007949         0.008243  0.011477
# tot_hi_cred_lim              0.334170     0.334169         0.334197 -0.118486
# total_bal_ex_mort            0.275413     0.275413         0.275419  0.004525
# total_il_high_credit_limit   0.200318     0.200315         0.200319 -0.002747
# classes                     -0.072908    -0.072978        -0.072597 -0.263577
#
#                             installment  annual_inc       dti  delinq_2yrs  \
# loan_amnt                      0.953021    0.309873  0.032195    -0.002138
# funded_amnt                    0.953674    0.309765  0.032588    -0.001945
# funded_amnt_inv                0.952313    0.309242  0.033657    -0.001645
# int_rate                       0.155666   -0.071362  0.146165     0.047965
# installment                    1.000000    0.300753  0.035986     0.007124
# annual_inc                     0.300753    1.000000 -0.139055     0.040924
# dti                            0.035986   -0.139055  1.000000    -0.008023
# delinq_2yrs                    0.007124    0.040924 -0.008023     1.000000
# fico_range_low                 0.051494    0.069903 -0.060032    -0.174090
# fico_range_high                0.051493    0.069904 -0.060035    -0.174088
# inq_last_6mths                 0.002737    0.031598 -0.009542     0.022412
# open_acc                       0.176024    0.134801  0.222143     0.052478
# pub_rec                       -0.052988   -0.004803 -0.030566    -0.020327
# revol_bal                      0.303342    0.284923  0.107710    -0.027881
# revol_util                     0.124952    0.035590  0.139436    -0.011202
# total_acc                      0.184598    0.175246  0.171435     0.119579
# out_prncp                      0.095007    0.018582  0.018349     0.004917
# out_prncp_inv                  0.095000    0.018583  0.018346     0.004915
# recoveries                     0.168780    0.027375  0.047194     0.017965
# collection_recovery_fee        0.162029    0.027231  0.047751     0.018590
# last_pymnt_amnt                0.432396    0.177731 -0.002852    -0.016859
# last_fico_range_high           0.035247    0.066452 -0.074253    -0.072732
# last_fico_range_low            0.036046    0.059827 -0.044970    -0.035930
# collections_12_mths_ex_med    -0.014181   -0.003954 -0.003189     0.071017
# acc_now_delinq                 0.004239    0.013429  0.002823     0.123928
# tot_coll_amt                  -0.002896    0.000010 -0.002880    -0.000335
# tot_cur_bal                    0.283254    0.395615  0.005928     0.057641
# acc_open_past_24mths           0.023351    0.056872  0.117854    -0.054050
# avg_cur_bal                    0.202667    0.305661 -0.084362     0.044907
# bc_open_to_buy                 0.165162    0.157346 -0.058959    -0.053702
# bc_util                        0.073153   -0.003034  0.142599    -0.008944
# chargeoff_within_12_mths       0.001455    0.008972 -0.002726     0.142133
# delinq_amnt                    0.001470    0.006568 -0.004269     0.030182
# mort_acc                       0.189466    0.212430 -0.028550     0.073332
# num_accts_ever_120_pd         -0.041318    0.016954 -0.033432     0.215394
# num_actv_bc_tl                 0.197567    0.104187  0.126502    -0.042993
# num_actv_rev_tl                0.158999    0.073012  0.189363    -0.004920
# num_bc_sats                    0.206650    0.122157  0.078955    -0.032389
# num_bc_tl                      0.183223    0.126115  0.050344     0.031794
# num_il_tl                      0.061786    0.100921  0.172610     0.084854
# num_op_rev_tl                  0.161779    0.078527  0.135582     0.006303
# num_rev_accts                  0.157494    0.101611  0.098314     0.077157
# num_rev_tl_bal_gt_0            0.158126    0.071899  0.191467    -0.008683
# num_sats                       0.171590    0.132132  0.215098     0.047464
# num_tl_30dpd                   0.004671    0.012177  0.004360     0.103982
# num_tl_90g_dpd_24m            -0.016399    0.007510 -0.013967     0.656164
# num_tl_op_past_12m             0.000162    0.052413  0.068868    -0.025121
# pct_tl_nvr_dlq                 0.070509   -0.007275  0.072104    -0.444748
# percent_bc_gt_75               0.040028   -0.016370  0.127592    -0.010852
# pub_rec_bankruptcies          -0.085199   -0.043951 -0.016726    -0.047360
# tax_liens                      0.014752    0.037793 -0.022822     0.011169
# tot_hi_cred_lim                0.301477    0.408800  0.015190     0.058910
# total_bal_ex_mort              0.260119    0.315126  0.223567     0.032243
# total_il_high_credit_limit     0.185541    0.262025  0.252218     0.062321
# classes                       -0.057873    0.039071 -0.084895    -0.020347
#
#                             fico_range_low  fico_range_high  ...  \
# loan_amnt                         0.101643         0.101642  ...
# funded_amnt                       0.100813         0.100812  ...
# funded_amnt_inv                   0.100030         0.100029  ...
# int_rate                         -0.403169        -0.403166  ...
# installment                       0.051494         0.051493  ...
# annual_inc                        0.069903         0.069904  ...
# dti                              -0.060032        -0.060035  ...
# delinq_2yrs                      -0.174090        -0.174088  ...
# fico_range_low                    1.000000         1.000000  ...
# fico_range_high                   1.000000         1.000000  ...
# inq_last_6mths                   -0.086113        -0.086113  ...
# open_acc                          0.017038         0.017037  ...
# pub_rec                          -0.191011        -0.191009  ...
# revol_bal                         0.025751         0.025749  ...
# revol_util                       -0.459067        -0.459066  ...
# total_acc                         0.020993         0.020992  ...
# out_prncp                         0.000762         0.000763  ...
# out_prncp_inv                     0.000766         0.000767  ...
# recoveries                       -0.058543        -0.058543  ...
# collection_recovery_fee          -0.056584        -0.056583  ...
# last_pymnt_amnt                   0.104774         0.104774  ...
# last_fico_range_high              0.342210         0.342209  ...
# last_fico_range_low               0.245194         0.245193  ...
# collections_12_mths_ex_med       -0.069024        -0.069023  ...
# acc_now_delinq                   -0.039043        -0.039042  ...
# tot_coll_amt                     -0.015907        -0.015907  ...
# tot_cur_bal                       0.133941         0.133940  ...
# acc_open_past_24mths             -0.101059        -0.101061  ...
# avg_cur_bal                       0.124878         0.124879  ...
# bc_open_to_buy                    0.512248         0.512251  ...
# bc_util                          -0.480634        -0.480632  ...
# chargeoff_within_12_mths         -0.052619        -0.052618  ...
# delinq_amnt                      -0.011678        -0.011677  ...
# mort_acc                          0.097311         0.097312  ...
# num_accts_ever_120_pd            -0.196383        -0.196380  ...
# num_actv_bc_tl                   -0.110028        -0.110029  ...
# num_actv_rev_tl                  -0.187546        -0.187546  ...
# num_bc_sats                       0.063170         0.063169  ...
# num_bc_tl                         0.056203         0.056202  ...
# num_il_tl                        -0.014185        -0.014188  ...
# num_op_rev_tl                     0.016935         0.016934  ...
# num_rev_accts                     0.022658         0.022658  ...
# num_rev_tl_bal_gt_0              -0.186513        -0.186513  ...
# num_sats                          0.032683         0.032682  ...
# num_tl_30dpd                     -0.030364        -0.030363  ...
# num_tl_90g_dpd_24m               -0.101882        -0.101881  ...
# num_tl_op_past_12m               -0.092465        -0.092467  ...
# pct_tl_nvr_dlq                    0.300555         0.300552  ...
# percent_bc_gt_75                 -0.410429        -0.410426  ...
# pub_rec_bankruptcies             -0.202539        -0.202536  ...
# tax_liens                        -0.057341        -0.057341  ...
# tot_hi_cred_lim                   0.195576         0.195577  ...
# total_bal_ex_mort                 0.031953         0.031951  ...
# total_il_high_credit_limit        0.062800         0.062798  ...
# classes                           0.129188         0.129186  ...
#
#                             num_tl_90g_dpd_24m  num_tl_op_past_12m  \
# loan_amnt                            -0.021811           -0.020131
# funded_amnt                          -0.021812           -0.020133
# funded_amnt_inv                      -0.021826           -0.020149
# int_rate                              0.026583            0.206641
# installment                          -0.016399            0.000162
# annual_inc                            0.007510            0.052413
# dti                                  -0.013967            0.068868
# delinq_2yrs                           0.656164           -0.025121
# fico_range_low                       -0.101882           -0.092465
# fico_range_high                      -0.101881           -0.092467
# inq_last_6mths                        0.031360            0.316861
# open_acc                              0.011561            0.367172
# pub_rec                              -0.000668            0.083674
# revol_bal                            -0.033468           -0.025593
# revol_util                           -0.011085           -0.218025
# total_acc                             0.070575            0.328138
# out_prncp                             0.000428            0.009914
# out_prncp_inv                         0.000429            0.009911
# recoveries                            0.004116            0.053904
# collection_recovery_fee               0.004434            0.053707
# last_pymnt_amnt                      -0.017668            0.023831
# last_fico_range_high                 -0.038160           -0.122611
# last_fico_range_low                  -0.020406           -0.089385
# collections_12_mths_ex_med            0.104698            0.014081
# acc_now_delinq                        0.059901           -0.005989
# tot_coll_amt                          0.001009            0.004737
# tot_cur_bal                           0.008401            0.084882
# acc_open_past_24mths                 -0.032303            0.758237
# avg_cur_bal                           0.010646           -0.050049
# bc_open_to_buy                       -0.041072            0.105090
# bc_util                              -0.012482           -0.186214
# chargeoff_within_12_mths              0.214325            0.001901
# delinq_amnt                           0.041912           -0.001686
# mort_acc                              0.033374            0.054396
# num_accts_ever_120_pd                 0.309943            0.080333
# num_actv_bc_tl                       -0.033677            0.160583
# num_actv_rev_tl                      -0.017884            0.257452
# num_bc_sats                          -0.020621            0.236342
# num_bc_tl                             0.015924            0.217824
# num_il_tl                             0.069554            0.191526
# num_op_rev_tl                        -0.025182            0.346469
# num_rev_accts                         0.029829            0.296044
# num_rev_tl_bal_gt_0                  -0.025356            0.244594
# num_sats                              0.009300            0.365146
# num_tl_30dpd                          0.006054           -0.006006
# num_tl_90g_dpd_24m                    1.000000           -0.001404
# num_tl_op_past_12m                   -0.001404            1.000000
# pct_tl_nvr_dlq                       -0.268758            0.008613
# percent_bc_gt_75                     -0.013188           -0.173209
# pub_rec_bankruptcies                 -0.008100            0.094430
# tax_liens                             0.002016            0.016563
# tot_hi_cred_lim                       0.005872            0.089110
# total_bal_ex_mort                     0.015769            0.120172
# total_il_high_credit_limit            0.033004            0.141766
# classes                              -0.009805           -0.084731
#
#                             pct_tl_nvr_dlq  percent_bc_gt_75  \
# loan_amnt                         0.087934          0.020342
# funded_amnt                       0.087934          0.020341
# funded_amnt_inv                   0.087948          0.020290
# int_rate                         -0.063701          0.248037
# installment                       0.070509          0.040028
# annual_inc                       -0.007275         -0.016370
# dti                               0.072104          0.127592
# delinq_2yrs                      -0.444748         -0.010852
# fico_range_low                    0.300555         -0.410429
# fico_range_high                   0.300552         -0.410426
# inq_last_6mths                   -0.032253         -0.067344
# open_acc                          0.109034         -0.095612
# pub_rec                          -0.026497         -0.044444
# revol_bal                         0.114909          0.128369
# revol_util                       -0.016431          0.727165
# total_acc                         0.016215         -0.071838
# out_prncp                        -0.007197         -0.018080
# out_prncp_inv                    -0.007196         -0.018081
# recoveries                        0.000265          0.043822
# collection_recovery_fee          -0.001048          0.040385
# last_pymnt_amnt                   0.057681         -0.049763
# last_fico_range_high              0.104086         -0.166494
# last_fico_range_low               0.058719         -0.113356
# collections_12_mths_ex_med       -0.046268         -0.032588
# acc_now_delinq                   -0.047552         -0.022940
# tot_coll_amt                     -0.014120         -0.006817
# tot_cur_bal                       0.014382          0.027970
# acc_open_past_24mths              0.059152         -0.163760
# avg_cur_bal                      -0.042943          0.058922
# bc_open_to_buy                    0.158435         -0.441321
# bc_util                          -0.018333          0.844756
# chargeoff_within_12_mths         -0.084713         -0.013162
# delinq_amnt                      -0.014160         -0.006439
# mort_acc                         -0.035370          0.001889
# num_accts_ever_120_pd            -0.568331         -0.032052
# num_actv_bc_tl                    0.126007          0.034182
# num_actv_rev_tl                   0.091644          0.094839
# num_bc_sats                       0.136761         -0.169033
# num_bc_tl                         0.048173         -0.148005
# num_il_tl                         0.002474          0.018047
# num_op_rev_tl                     0.133580         -0.140296
# num_rev_accts                     0.033742         -0.120670
# num_rev_tl_bal_gt_0               0.100909          0.101658
# num_sats                          0.111686         -0.095461
# num_tl_30dpd                     -0.038773         -0.017017
# num_tl_90g_dpd_24m               -0.268758         -0.013188
# num_tl_op_past_12m                0.008613         -0.173209
# pct_tl_nvr_dlq                    1.000000         -0.004135
# percent_bc_gt_75                 -0.004135          1.000000
# pub_rec_bankruptcies              0.032089         -0.041690
# tax_liens                        -0.033663         -0.018228
# tot_hi_cred_lim                   0.024896         -0.016810
# total_bal_ex_mort                 0.063180          0.061761
# total_il_high_credit_limit        0.015613          0.010372
# classes                           0.014573         -0.060528
#
#                             pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# loan_amnt                              -0.092956   0.007817         0.334170
# funded_amnt                            -0.092761   0.007949         0.334169
# funded_amnt_inv                        -0.092393   0.008243         0.334197
# int_rate                                0.058580   0.011477        -0.118486
# installment                            -0.085199   0.014752         0.301477
# annual_inc                             -0.043951   0.037793         0.408800
# dti                                    -0.016726  -0.022822         0.015190
# delinq_2yrs                            -0.047360   0.011169         0.058910
# fico_range_low                         -0.202539  -0.057341         0.195576
# fico_range_high                        -0.202536  -0.057341         0.195577
# inq_last_6mths                          0.073295   0.008850         0.030790
# open_acc                               -0.021868  -0.004509         0.281847
# pub_rec                                 0.647560   0.701350        -0.075084
# revol_bal                              -0.115992  -0.012126         0.463819
# revol_util                             -0.085778  -0.011014         0.027776
# total_acc                               0.033614  -0.018891         0.334283
# out_prncp                               0.002076   0.000629         0.009402
# out_prncp_inv                           0.002073   0.000629         0.009404
# recoveries                             -0.001641   0.004188         0.013300
# collection_recovery_fee                 0.000369   0.004823         0.014091
# last_pymnt_amnt                        -0.025370  -0.010357         0.235021
# last_fico_range_high                   -0.063487  -0.020133         0.139315
# last_fico_range_low                    -0.049310  -0.017056         0.126286
# collections_12_mths_ex_med              0.000134   0.012738        -0.011427
# acc_now_delinq                         -0.009200   0.007259         0.027202
# tot_coll_amt                            0.000495   0.002557        -0.001590
# tot_cur_bal                            -0.097681  -0.002920         0.973010
# acc_open_past_24mths                    0.115018   0.014275         0.104902
# avg_cur_bal                            -0.081224   0.001055         0.794453
# bc_open_to_buy                         -0.095654  -0.016777         0.261470
# bc_util                                -0.038911  -0.010297        -0.014916
# chargeoff_within_12_mths               -0.010554  -0.001602         0.007614
# delinq_amnt                            -0.000564   0.002813         0.020863
# mort_acc                                0.006211  -0.011868         0.531346
# num_accts_ever_120_pd                  -0.022792   0.012850         0.006766
# num_actv_bc_tl                         -0.061622   0.010687         0.128773
# num_actv_rev_tl                        -0.014496   0.007001         0.118132
# num_bc_sats                            -0.049801   0.002509         0.168065
# num_bc_tl                               0.011768  -0.011588         0.182286
# num_il_tl                              -0.006650  -0.011872         0.190361
# num_op_rev_tl                           0.002264  -0.000732         0.146241
# num_rev_accts                           0.053802  -0.018017         0.185202
# num_rev_tl_bal_gt_0                    -0.023133   0.007535         0.117539
# num_sats                               -0.033682  -0.006832         0.281907
# num_tl_30dpd                           -0.012969   0.005268         0.026858
# num_tl_90g_dpd_24m                     -0.008100   0.002016         0.005872
# num_tl_op_past_12m                      0.094430   0.016563         0.089110
# pct_tl_nvr_dlq                          0.032089  -0.033663         0.024896
# percent_bc_gt_75                       -0.041690  -0.018228        -0.016810
# pub_rec_bankruptcies                    1.000000   0.035383        -0.107317
# tax_liens                               0.035383   1.000000        -0.001726
# tot_hi_cred_lim                        -0.107317  -0.001726         1.000000
# total_bal_ex_mort                      -0.077376  -0.001940         0.507862
# total_il_high_credit_limit             -0.035664   0.005977         0.401361
# classes                                -0.025750  -0.010247         0.077608
#
#                             total_bal_ex_mort  total_il_high_credit_limit  \
# loan_amnt                            0.275413                    0.200318
# funded_amnt                          0.275413                    0.200315
# funded_amnt_inv                      0.275419                    0.200319
# int_rate                             0.004525                   -0.002747
# installment                          0.260119                    0.185541
# annual_inc                           0.315126                    0.262025
# dti                                  0.223567                    0.252218
# delinq_2yrs                          0.032243                    0.062321
# fico_range_low                       0.031953                    0.062800
# fico_range_high                      0.031951                    0.062798
# inq_last_6mths                       0.036628                    0.044760
# open_acc                             0.400299                    0.361762
# pub_rec                             -0.058000                   -0.022949
# revol_bal                            0.504233                    0.119308
# revol_util                           0.120968                    0.031970
# total_acc                            0.429953                    0.417639
# out_prncp                            0.018527                    0.021167
# out_prncp_inv                        0.018527                    0.021167
# recoveries                           0.048415                    0.042282
# collection_recovery_fee              0.049332                    0.043495
# last_pymnt_amnt                      0.157128                    0.127177
# last_fico_range_high                 0.027659                    0.020217
# last_fico_range_low                  0.044595                    0.038831
# collections_12_mths_ex_med          -0.010474                    0.001188
# acc_now_delinq                       0.009823                    0.016494
# tot_coll_amt                        -0.001848                    0.000953
# tot_cur_bal                          0.518625                    0.406836
# acc_open_past_24mths                 0.160219                    0.190003
# avg_cur_bal                          0.290178                    0.206962
# bc_open_to_buy                       0.113192                    0.062830
# bc_util                              0.082621                    0.017869
# chargeoff_within_12_mths            -0.002572                    0.005671
# delinq_amnt                          0.002881                    0.002002
# mort_acc                             0.149615                    0.105429
# num_accts_ever_120_pd                0.016866                    0.047897
# num_actv_bc_tl                       0.147762                    0.029323
# num_actv_rev_tl                      0.142375                    0.024950
# num_bc_sats                          0.140892                    0.042373
# num_bc_tl                            0.124406                    0.045311
# num_il_tl                            0.512464                    0.587654
# num_op_rev_tl                        0.132308                    0.043119
# num_rev_accts                        0.127227                    0.054640
# num_rev_tl_bal_gt_0                  0.146105                    0.026709
# num_sats                             0.400457                    0.362345
# num_tl_30dpd                         0.009719                    0.014953
# num_tl_90g_dpd_24m                   0.015769                    0.033004
# num_tl_op_past_12m                   0.120172                    0.141766
# pct_tl_nvr_dlq                       0.063180                    0.015613
# percent_bc_gt_75                     0.061761                    0.010372
# pub_rec_bankruptcies                -0.077376                   -0.035664
# tax_liens                           -0.001940                    0.005977
# tot_hi_cred_lim                      0.507862                    0.401361
# total_bal_ex_mort                    1.000000                    0.873296
# total_il_high_credit_limit           0.873296                    1.000000
# classes                              0.002165                   -0.001483
#
#                              classes
# loan_amnt                  -0.072908
# funded_amnt                -0.072978
# funded_amnt_inv            -0.072597
# int_rate                   -0.263577
# installment                -0.057873
# annual_inc                  0.039071
# dti                        -0.084895
# delinq_2yrs                -0.020347
# fico_range_low              0.129188
# fico_range_high             0.129186
# inq_last_6mths             -0.061624
# open_acc                   -0.026775
# pub_rec                    -0.026086
# revol_bal                   0.020725
# revol_util                 -0.054068
# total_acc                   0.016556
# out_prncp                  -0.211324
# out_prncp_inv              -0.211313
# recoveries                 -0.477313
# collection_recovery_fee    -0.453070
# last_pymnt_amnt             0.358162
# last_fico_range_high        0.664926
# last_fico_range_low         0.567334
# collections_12_mths_ex_med -0.017173
# acc_now_delinq             -0.003277
# tot_coll_amt                0.000482
# tot_cur_bal                 0.070672
# acc_open_past_24mths       -0.099427
# avg_cur_bal                 0.078310
# bc_open_to_buy              0.078908
# bc_util                    -0.059209
# chargeoff_within_12_mths   -0.003621
# delinq_amnt                -0.002729
# mort_acc                    0.080139
# num_accts_ever_120_pd      -0.011646
# num_actv_bc_tl             -0.040996
# num_actv_rev_tl            -0.068844
# num_bc_sats                -0.014645
# num_bc_tl                   0.023442
# num_il_tl                  -0.004791
# num_op_rev_tl              -0.031303
# num_rev_accts               0.010818
# num_rev_tl_bal_gt_0        -0.067071
# num_sats                   -0.025043
# num_tl_30dpd               -0.002311
# num_tl_90g_dpd_24m         -0.009805
# num_tl_op_past_12m         -0.084731
# pct_tl_nvr_dlq              0.014573
# percent_bc_gt_75           -0.060528
# pub_rec_bankruptcies       -0.025750
# tax_liens                  -0.010247
# tot_hi_cred_lim             0.077608
# total_bal_ex_mort           0.002165
# total_il_high_credit_limit -0.001483
# classes                     1.000000
#
# [55 rows x 55 columns]

# %% [markdown]
# It is clear that it is not feasible to manually interpret the correlations between features. Additionally, there are too many features for a Heatmap to have any chance of showing a grid!

# %%
data.isnull().sum().sort_values(ascending=False)
# Out:
# desc                          1247945
# emp_title                       88473
# emp_length                      80850
# pct_tl_nvr_dlq                  70430
# avg_cur_bal                     70299
# num_rev_accts                   70277
# num_tl_op_past_12m              70276
# num_tl_30dpd                    70276
# num_accts_ever_120_pd           70276
# num_bc_tl                       70276
# num_il_tl                       70276
# num_op_rev_tl                   70276
# num_rev_tl_bal_gt_0             70276
# num_actv_rev_tl                 70276
# num_tl_90g_dpd_24m              70276
# num_actv_bc_tl                  70276
# tot_coll_amt                    70276
# tot_hi_cred_lim                 70276
# tot_cur_bal                     70276
# total_il_high_credit_limit      70276
# bc_util                         65042
# percent_bc_gt_75                64672
# bc_open_to_buy                  64258
# num_bc_sats                     58590
# num_sats                        58590
# mort_acc                        50030
# total_bal_ex_mort               50030
# acc_open_past_24mths            50030
# title                           17008
# pub_rec_bankruptcies             1365
#                                ...
# delinq_amnt                        29
# annual_inc                          4
# pymnt_plan                          0
# issue_d                             0
# funded_amnt                         0
# purpose                             0
# verification_status                 0
# home_ownership                      0
# funded_amnt_inv                     0
# grade                               0
# installment                         0
# int_rate                            0
# term                                0
# classes                             0
# last_fico_range_low                 0
# addr_state                          0
# fico_range_low                      0
# fico_range_high                     0
# revol_bal                           0
# out_prncp                           0
# out_prncp_inv                       0
# recoveries                          0
# collection_recovery_fee             0
# last_pymnt_amnt                     0
# last_fico_range_high                0
# debt_settlement_flag                0
# application_type                    0
# hardship_flag                       0
# disbursement_method                 0
# loan_amnt                           0
# Length: 72, dtype: int64

# %% [markdown]
# The prevalence of missing values reveals some potential overlap in rows missing a majority of data. Hopefully, by removing one set of missing values in a column, this cleans the columns with nearly identical quantities. In particular, a cursory glance reveals that more than 15 features with a clustering around 70,200 missing values.

# %%
data.shape
# Out:
# (1373915, 72)

# %%
# 'num_actv_bc_tl' is the first attempt to remove the majority of the 70,200 missing values across 17 features
data = data[data['num_actv_bc_tl'].notna()]

# %%
data['title'].value_counts()
# Out:
# Debt consolidation                     673940
# Credit card refinancing                254337
# Home improvement                        76629
# Other                                   68380
# Major purchase                          24644
# Medical expenses                        13883
# Business                                11962
# Car financing                           11413
# Debt Consolidation                      11190
# Moving and relocation                    8147
# Vacation                                 8120
# Home buying                              6108
# Consolidation                            4298
# debt consolidation                       3658
# consolidation                            1715
# Credit Card Consolidation                1693
# Debt Consolidation Loan                  1335
# Consolidation Loan                       1310
# Home Improvement                         1127
# Personal Loan                            1119
# Credit Card Refinance                    1085
# Credit Card Payoff                       1059
# Consolidate                              1012
# Green loan                                738
# Loan                                      679
# Personal                                  671
# Freedom                                   635
# consolidate                               596
# Payoff                                    565
# Debt                                      557
#                                         ...
# Pay Credit                                  1
# DEBTFREE4ME                                 1
# Chase pay off                               1
# crcard-homeimpr                             1
# A better future                             1
# Credit Card Debt Payoff Loan                1
# Paying off all my debt                      1
# Help me save more for the future            1
# consolidater2                               1
# Long time dream                             1
# Debt consolidtation                         1
# BYEBYECARDS                                 1
# just need to pay off  little bills          1
# Refin Roof and Finish Kitchen               1
# Personal Refinancing Plan                   1
# love being me                               1
# Adding a bathroom                           1
# Hello affordable interest                   1
# Debt Consolidation For New Home             1
# Credit Card Debt Slayer                     1
# credit card paynebts                        1
# get me free                                 1
# Higher interest credit payoff               1
# Credit card freedom !                       1
# PAYMENT  CARD                               1
# Cards paid                                  1
# new rates                                   1
# Mission Debt Free                           1
# To put all debt in one payment              1
# First step to freedom                       1
# Name: title, Length: 39098, dtype: int64

# %%
data.isnull().sum().sort_values(ascending=False)
# Out:
# desc                          1224002
# emp_title                       84135
# emp_length                      78789
# title                           16995
# bc_util                         14728
# percent_bc_gt_75                14371
# bc_open_to_buy                  13957
# revol_util                        806
# dti                               403
# pct_tl_nvr_dlq                    154
# avg_cur_bal                        23
# inq_last_6mths                      1
# num_rev_accts                       1
# pub_rec                             0
# earliest_cr_line                    0
# open_acc                            0
# revol_bal                           0
# total_acc                           0
# out_prncp                           0
# fico_range_high                     0
# out_prncp_inv                       0
# fico_range_low                      0
# classes                             0
# purpose                             0
# delinq_2yrs                         0
# addr_state                          0
# collection_recovery_fee             0
# pymnt_plan                          0
# issue_d                             0
# verification_status                 0
#                                ...
# disbursement_method                 0
# hardship_flag                       0
# total_il_high_credit_limit          0
# total_bal_ex_mort                   0
# tot_hi_cred_lim                     0
# tax_liens                           0
# pub_rec_bankruptcies                0
# num_tl_op_past_12m                  0
# num_tl_90g_dpd_24m                  0
# num_tl_30dpd                        0
# num_sats                            0
# num_rev_tl_bal_gt_0                 0
# num_op_rev_tl                       0
# num_il_tl                           0
# num_bc_tl                           0
# num_bc_sats                         0
# num_actv_rev_tl                     0
# num_actv_bc_tl                      0
# num_accts_ever_120_pd               0
# mort_acc                            0
# delinq_amnt                         0
# chargeoff_within_12_mths            0
# acc_open_past_24mths                0
# tot_cur_bal                         0
# tot_coll_amt                        0
# acc_now_delinq                      0
# application_type                    0
# collections_12_mths_ex_med          0
# debt_settlement_flag                0
# loan_amnt                           0
# Length: 72, dtype: int64

# %%
data = data[data['bc_util'].notna()]

# %%
data = data[data['emp_length'].notna()]

# %% [markdown]
# I drop the employment length missing values because, although likely to be underreported, it is worse to make up data here

# %%
#exploring the supplied purpose field for loans
data['purpose'].value_counts()
# Out:
# debt_consolidation    710891
# credit_card           270494
# home_improvement       76974
# other                  66793
# major_purchase         25068
# medical                13259
# small_business         12454
# car                    11741
# moving                  8087
# vacation                7791
# house                   6283
# wedding                  848
# renewable_energy         747
# educational                1
# Name: purpose, dtype: int64

# %%
#dropping educational as a purpose for loans due to there only being a single instance
data = data[data['purpose'] != 'educational']

# %%
data.shape
# Out:
# (1211430, 72)

# %% [markdown]
# ### Visualizing some preliminary EDA

# %%
data['loan_amnt'].hist(bins=30)
plt.title('Loan Amounts ($)', size=20);
plt.xlabel('$ Amount', size= 12);
plt.ylabel('Quantity of Loans', size=12);

# %% [markdown]
# **Thoughts:** There are clearly higher frequencies associated with loan amounts that are multiples of 5,000. If I am going to be creating bins to contain the information it will be necessary to guarantee that these spikes are in the middle of the bin. Potentially will be using the following ranges: 0-2500, 2500-7500, 7501-12500, 12501-17500, 17501-22500, 22501-27500, 27501-32500, 32501-37500 and finally 37501-42500.

# %%
data['annual_inc'].hist(bins=30)
plt.title('Annual Incomes', size=20);
plt.xlabel('$ Amount', size=12);
plt.ylabel('Frequency of Salaries', size=12);

# %% [markdown]
# **Thoughts:** It is immediately obvious there is something going on with the annual_inc column, most likely large outliers are present. This results in the absurd graph above, which I will need to investigate further. Before removing the outliers, the income ranges from

# %%
## SCATTER PLOT OF ANNUAL INCOME TO SHOW OUTLIERS

# %%
plt.scatter(data['annual_inc'], data['emp_length'])

# %%
data['avg_cur_bal'].hist(bins=25)
plt.title('Avg Current Balance', size = 20);
plt.xlabel('balance size', size = 12);
plt.ylabel('Frequency of Balances', size = 12);

# %%
## SCATTER PLOT OF AVG CURRENT BALANCE TO SHOW OUTLIERS

# %%
data['avg_cur_bal'].describe()
# Out:
# count    1.211430e+06
# mean     1.357119e+04
# std      1.611179e+04
# min      0.000000e+00
# 25%      3.185000e+03
# 50%      7.554000e+03
# 75%      1.885100e+04
# max      5.559250e+05
# Name: avg_cur_bal, dtype: float64

# %% [markdown]
# **Thoughts:** Another chart where outliers are most likely causing issues for our visualization of the data. This will most likely need to be capped at a certain amount in order to deal with outlier data. Checking the descriptive statistics with .describe enable us to see that there is a large jump from 75% to Max, indicating large values as the outliers as the mean is close to 75% as well.

# %% [markdown]
# ### Map based Visualizations- Target (1/0) by State, Amount Funded, Annual Income, Employment Length (maybe text length)
# This is done using Folium in combination with the following columns: loan_status, annual_inc, amt_funded and emp_length

# %%
#I will be using folium in order to show some map based data 
#https://python-graph-gallery.com/292-choropleth-map-with-folium/

data['emp_length'].value_counts()
# Out:
# 10+ years    428427
# 2 years      115957
# 3 years      102549
# < 1 year     102357
# 1 year        84178
# 5 years       79184
# 4 years       75793
# 6 years       59070
# 8 years       58362
# 7 years       56623
# 9 years       48930
# Name: emp_length, dtype: int64

# %% [markdown]
# ## Data Cleaning - dealing with outliers- IMPROVE VISUALIZATIONS
# annual_inc, avg_cur_bal

# %%
# capping the annual income at 300_000 in order to represent a more normal distribution and remove outliers
# data = data[data['annual_inc'] <= 350_000 ]

# %%
# capping the minimum of annual reported income at 1_000 as that data is unreliable
# data = data[data['annual_inc']> 500]

# %%
data['annual_inc'].hist(bins=35)
plt.title('Annual Incomes (No Outliers)', size=20);
plt.xlabel('Income Amount', size=12);
plt.ylabel('Frequency of Salaries', size=12);

# %%
# data = data[data['avg_cur_bal'] < 60_000]

# %%
data['avg_cur_bal'].hist(bins=35)
plt.title('Avg Current Balance (No Outliers)', size = 20);
plt.xlabel('balance size', size = 12);
plt.ylabel('Frequency of Balances', size = 12);

# %% [markdown]
# ### Looking at Text Fields:
# a handful of columns in this dataset are text based and need further investigation in order to determine how to manipulate them so they are more useful. As they are currently object data types we need to find a way to convert this data into numerical information. Two approaches immediately

# %%
data['emp_title'].value_counts()
# Out:
# Teacher                                     21355
# Manager                                     19772
# Owner                                       10641
# Registered Nurse                             8885
# RN                                           8585
# Supervisor                                   8370
# Driver                                       7708
# Sales                                        7593
# Project Manager                              6428
# Office Manager                               5580
# General Manager                              5289
# Director                                     5074
# owner                                        4681
# manager                                      4579
# Engineer                                     4314
# President                                    4260
# teacher                                      4102
# Vice President                               3572
# driver                                       3542
# Operations Manager                           3513
# Accountant                                   3314
# Sales Manager                                3103
# Attorney                                     3096
# Administrative Assistant                     3096
# Account Manager                              2798
# Police Officer                               2716
# Nurse                                        2701
# Technician                                   2617
# Analyst                                      2574
# sales                                        2548
#                                             ...
# Randall mechanical                              1
# Consultant in Technical Design                  1
# associate Creative director                     1
# FlyingJ                                         1
# tullett prebon                                  1
# Marketing NCOIC                                 1
# Development and Project Director                1
# Disdaply                                        1
# Director of Sofball                             1
# owner/oporator                                  1
# Government affairs specialist                   1
# The Washington Trust Company                    1
# Staffing & Classification Branch Head           1
# Gifted and Talented Coordinator                 1
# Artorius Management, LLC                        1
# lead administrator, voice/data                  1
# Liquidation officer                             1
# Slurry Productions                              1
# MANUFACTORING                                   1
# VP; Digital Channel Manager                     1
# Responsys Inc                                   1
# Warehouse Attendant                             1
# Office Supervisor for a cardio Thoracic         1
# principal business analyst                      1
# Atlantic Asset Management                       1
# OperationsSupervisor                            1
# Business Support Mgr                            1
# Sr. Mgr of Application Development              1
# Marketing Assistant Director                    1
# aviation electrician                            1
# Name: emp_title, Length: 341751, dtype: int64

# %%
data['title'].value_counts()
# Out:
# Debt consolidation                     628293
# Credit card refinancing                237167
# Home improvement                        69634
# Other                                   61647
# Major purchase                          22770
# Medical expenses                        12361
# Business                                11397
# Debt Consolidation                      10919
# Car financing                           10553
# Moving and relocation                    7399
# Vacation                                 7287
# Home buying                              5623
# Consolidation                            4154
# debt consolidation                       3422
# Credit Card Consolidation                1648
# consolidation                            1593
# Debt Consolidation Loan                  1303
# Consolidation Loan                       1277
# Personal Loan                            1083
# Credit Card Refinance                    1059
# Home Improvement                         1057
# Credit Card Payoff                       1023
# Consolidate                               972
# Green loan                                678
# Loan                                      660
# Personal                                  643
# Freedom                                   593
# consolidate                               562
# Debt                                      543
# Payoff                                    531
#                                         ...
# Beating High Interest Debt                  1
# Accelerated Debt Elimination                1
# YUCK                                        1
# Credit card close                           1
#  Pay off                                    1
# Debt Paydown Plan                           1
# Credit Cards be GONE                        1
# Debt Eradication Strategem 2012             1
# First loan                                  1
# Update my bungalow                          1
# God will help me                            1
# good move                                   1
# Pay Credit                                  1
# DEBTFREE4ME                                 1
# Chase pay off                               1
# Good Credit debt consolidation loan         1
# A better future                             1
# Credit Card Debt Payoff Loan                1
# Paying off all my debt                      1
# Help me save more for the future            1
# Long time dream                             1
# BYEBYECARDS                                 1
# just need to pay off  little bills          1
# Personal & Medical Loan                     1
# Refin Roof and Finish Kitchen               1
# love being me                               1
# Hello affordable interest                   1
# Debt Consolidation For New Home             1
# Credit Card Debt Slayer                     1
# First step to freedom                       1
# Name: title, Length: 37177, dtype: int64

# %%
data['desc'].value_counts()
# Out:
#                                                                                                                                                                                                                                                                                                                                                    23
#   Borrower added on 03/17/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                                              10
#   Borrower added on 03/10/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                                              10
#   Borrower added on 01/29/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                                               8
#   Borrower added on 02/19/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                                               7
#   Borrower added on 01/15/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                                               7
#   Borrower added on 01/06/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                                               6
#   Borrower added on 07/25/13 > Debt consolidation<br>                                                                                                                                                                                                                                                                                               6
#   Borrower added on 03/03/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                                               6
#   Borrower added on 03/05/14 > debt consolidation<br>                                                                                                                                                                                                                                                                                               6
#   Borrower added on 01/03/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                                               6
#   Borrower added on 01/27/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                                               6
#   Borrower added on 02/03/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                                               6
#   Borrower added on 02/19/14 > Debt Consolidation<br>                                                                                                                                                                                                                                                                                               6
#   Borrower added on 03/14/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                                               6
#   Borrower added on 03/07/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                                               6
#   Borrower added on 02/26/14 > Debt Consolidation<br>                                                                                                                                                                                                                                                                                               6
#   Borrower added on 03/18/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                                               6
#   Borrower added on 02/06/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                                               6
#   Borrower added on 12/19/13 > Debt consolidation<br>                                                                                                                                                                                                                                                                                               5
#   Borrower added on 02/25/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                                               5
#   Borrower added on 02/27/13 > Debt consolidation<br>                                                                                                                                                                                                                                                                                               5
#   Borrower added on 01/22/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                                               5
#   Borrower added on 10/01/12 > Debt consolidation<br>                                                                                                                                                                                                                                                                                               5
#   Borrower added on 01/17/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                                               5
#   Borrower added on 01/12/13 > Debt Consolidation<br>                                                                                                                                                                                                                                                                                               5
#   Borrower added on 02/05/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                                               5
#   Borrower added on 03/13/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                                               5
#   Borrower added on 02/25/14 > Debt consolidation.<br>                                                                                                                                                                                                                                                                                              5
#   Borrower added on 12/13/13 > Debt consolidation<br>                                                                                                                                                                                                                                                                                               5
#                                                                                                                                                                                                                                                                                                                                                    ..
#   Borrower added on 01/25/13 > I need this loan to consolidate/refinance a couple credit cards and provide funds for a small home update with new carpeting.<br>                                                                                                                                                                                    1
#   Borrower added on 02/21/14 > I have a couple of bills that I wish to consolidate.<br>                                                                                                                                                                                                                                                             1
#   Borrower added on 01/17/13 > This loan will be used to refinance four credit cards (i.e., Bank of America Visa, Capital One Visa, Banana Republic Visa, and Orchard Bank Master Card) with varying interest rates ranging from approximately 17.99% - 23.99%. Currently, my total credit card debt is approximately $17,000.<br>                  1
#   Borrower added on 03/04/14 > Pay off cc debt<br>                                                                                                                                                                                                                                                                                                  1
#   Borrower added on 03/14/14 > This loan will be utilized for consolidate revolving accumulated over several years for several purposes.<br>                                                                                                                                                                                                        1
#   Borrower added on 12/13/12 > Retire credit card and become debt free in three years or less.<br>                                                                                                                                                                                                                                                  1
#   Borrower added on 09/18/12 > The loan is for me and my Fiance to get married, have a nice honeymoon, and consolidate some of my debt from Credit Cards into a loan.<br>                                                                                                                                                                           1
#   Borrower added on 09/12/12 > Consolidate credit card debt and lower interest rate.<br><br> Borrower added on 09/12/12 > Credit card debt consolidation and lower interest rate.<br>                                                                                                                                                               1
#   Borrower added on 11/09/12 > Have a few very high interest credit cards that I cannot seem to get down no matter how much I put on them. This loan seems the best way to allow me to have some peace of mind with my finances.<br>                                                                                                                1
#   Borrower added on 01/17/13 > Take away credit card balance<br>                                                                                                                                                                                                                                                                                    1
#   Borrower added on 02/06/13 > I am using this money to pay off my high interest credit cards more quickly.<br>                                                                                                                                                                                                                                     1
#   Borrower added on 06/26/13 > medical bills,credit card pay off to cancel and start over before its to late<br>                                                                                                                                                                                                                                    1
#   Borrower added on 10/15/12 > Credit card consolidation<br><br>  Borrower added on 10/15/12 > Debt consolidation...pay high interest credit cards<br>                                                                                                                                                                                              1
#   Borrower added on 02/04/14 > This loan is for paying off my credit card debts.<br><br> Borrower added on 02/04/14 > This loan is for paying of my credit card debts,I need to eliminate  my multiple monthly payments on my credit cards, and just pay one bill so I can save on all those interest charge.<br>                                   1
#   Borrower added on 03/25/13 > I would like to consolidate several high interest debts to pay them off in three years or less.<br>                                                                                                                                                                                                                  1
#   Borrower added on 08/20/13 > i call this a relax lone we would like to get an rv trailer so we can get away and enjoy life and unwind for the weekend<br>                                                                                                                                                                                         1
#   Borrower added on 12/02/13 > I will use the loan to pay off my low credit card debt at a lower rate enabling me to pay off my loan quicker freeing me from debt. The money owed on the loan will be set up as an automatic withdraw assuring timely payment.<br>                                                                                  1
#   Borrower added on 01/28/13 > I need to replace parts on my vehicle quickly, since it is my only mode of transportation.<br>                                                                                                                                                                                                                       1
#   Borrower added on 10/12/12 > I am consolidating all of my debt and reducing my payment by over half. We will be able to take our first vacation in over 6 years.<br>                                                                                                                                                                              1
#   Borrower added on 08/18/12 > Consolidate High interest Credit cards.<br><br>  Borrower added on 08/23/12 > Credit card debt is $11,351.92 , 75% of which is at 19% interest. the rest is at 0%. I pay close to 350 a month and it doesn't feel like its going anywhere. I want to know that ill be out of this mess in 36 Months or less.<br>     1
#   Borrower added on 03/18/13 > This loan will be used to pay off credit card bills , so i can have one monthly payment.<br>                                                                                                                                                                                                                         1
#   Borrower added on 01/25/13 > Credit card consolidation<br>                                                                                                                                                                                                                                                                                        1
#   Borrower added on 05/18/13 > Using the debt snowball, but need a bolus to get through high interest rates. Ready for zero!<br><br> Borrower added on 05/18/13 > Hoping to get out of high interest credit card debt ASAP!  Just need a little bolus to get things going...Planning for daughter's college fund.<br>                               1
#   Borrower added on 02/15/14 > I need to catch up on bills and pay off high monthly obligations. Also personal debt and needs.<br>                                                                                                                                                                                                                  1
#   Borrower added on 10/05/12 > To consolidate the last of my credit card bills....<br><br>  Borrower added on 10/06/12 > This loan is to pay off the last of the credit card dept. Allowing me to finally be rid of them all.<br>                                                                                                                   1
#   Borrower added on 05/31/13 > I have credit card debt I would like to consolidate and pay off.  I have cash to pay off the balance of the US Bank and Sam's Club balances and would like this loan to consolidate the USAA and Wells Fargo credit Cards.<br>                                                                                       1
#   Borrower added on 03/10/14 > Refinance my current loan(60 months to 36 months) and clear out a credit card.<br>                                                                                                                                                                                                                                   1
#   Borrower added on 09/17/13 > Payoff High Credit Card Balances<br>                                                                                                                                                                                                                                                                                 1
#   Borrower added on 08/27/12 > Am wanting to consolidate all of my debt in to what I feel is a very comfortable payment and in doing so, save alot of interest and gain the peace of mind knowing I'm debt free in three yrs( hopefully much closer to to two years)<br>                                                                            1
#   Borrower added on 04/03/13 > Consolidate credit cards<br><br> Borrower added on 04/03/13 > I would like to pay off all my credit card balances.<br><br> Borrower added on 04/03/13 > Consolidate credit card bills<br>                                                                                                                            1
# Name: desc, Length: 73999, dtype: int64

# %% [markdown]
# **Thoughts:** With 341_751 individual unique values for emp_title, 37_177 for title and finally 73_999 in desc, there is way too much complexity for me to tackle this directly. After changing them to str, I will have to incorporate NLP into my project. Theoretically I would want to reduce the complexity in similar titles, correct for spelling issues, and a litany of other approaches that are not feasible for my time schedule.
#
# For this project I will be looking to measure the length of all three individual columns and engineer three new columns, then combine all user-generated text fields into one aggregated column named all_text

# %% [markdown]
# ### Data cleaning- light pruning (columns that have 2000 NaNs or less)

# %%
#i wrote a function to automate the dropping of rows that contain NaN in columns which had 2000 or less NaN

def drop_na(df):
    cols=data.columns
    subset=[]
    for i in cols:
        #check number of missing values
        missing_vals = df[i].isnull().sum()
        #if less than 2000 na, drop the rows containing na
        if missing_vals <= 2000:
            subset.append(i)
            
        df.dropna(subset=subset,inplace=True)
        print(f'finished checking column  "{i}"')
    print('FINISHED ALL!')

drop_na(data)
# Out:
# finished checking column  "loan_amnt"
# finished checking column  "funded_amnt"
# finished checking column  "funded_amnt_inv"
# finished checking column  "term"
# finished checking column  "int_rate"
# finished checking column  "installment"
# finished checking column  "grade"
# finished checking column  "emp_title"
# finished checking column  "emp_length"
# finished checking column  "home_ownership"
# finished checking column  "annual_inc"
# finished checking column  "verification_status"
# finished checking column  "issue_d"
# finished checking column  "pymnt_plan"
# finished checking column  "desc"
# finished checking column  "purpose"
# finished checking column  "title"
# finished checking column  "addr_state"
# finished checking column  "dti"
# finished checking column  "delinq_2yrs"
# finished checking column  "earliest_cr_line"
# finished checking column  "fico_range_low"
# finished checking column  "fico_range_high"
# finished checking column  "inq_last_6mths"
# finished checking column  "open_acc"
# finished checking column  "pub_rec"
# finished checking column  "revol_bal"
# finished checking column  "revol_util"
# finished checking column  "total_acc"
# finished checking column  "out_prncp"
# finished checking column  "out_prncp_inv"
# finished checking column  "recoveries"
# finished checking column  "collection_recovery_fee"
# finished checking column  "last_pymnt_amnt"
# finished checking column  "last_fico_range_high"
# finished checking column  "last_fico_range_low"
# finished checking column  "collections_12_mths_ex_med"
# finished checking column  "application_type"
# finished checking column  "acc_now_delinq"
# finished checking column  "tot_coll_amt"
# finished checking column  "tot_cur_bal"
# finished checking column  "acc_open_past_24mths"
# finished checking column  "avg_cur_bal"
# finished checking column  "bc_open_to_buy"
# finished checking column  "bc_util"
# finished checking column  "chargeoff_within_12_mths"
# finished checking column  "delinq_amnt"
# finished checking column  "mort_acc"
# finished checking column  "num_accts_ever_120_pd"
# finished checking column  "num_actv_bc_tl"
# finished checking column  "num_actv_rev_tl"
# finished checking column  "num_bc_sats"
# finished checking column  "num_bc_tl"
# finished checking column  "num_il_tl"
# finished checking column  "num_op_rev_tl"
# finished checking column  "num_rev_accts"
# finished checking column  "num_rev_tl_bal_gt_0"
# finished checking column  "num_sats"
# finished checking column  "num_tl_30dpd"
# finished checking column  "num_tl_90g_dpd_24m"
# finished checking column  "num_tl_op_past_12m"
# finished checking column  "pct_tl_nvr_dlq"
# finished checking column  "percent_bc_gt_75"
# finished checking column  "pub_rec_bankruptcies"
# finished checking column  "tax_liens"
# finished checking column  "tot_hi_cred_lim"
# finished checking column  "total_bal_ex_mort"
# finished checking column  "total_il_high_credit_limit"
# finished checking column  "hardship_flag"
# finished checking column  "disbursement_method"
# finished checking column  "debt_settlement_flag"
# finished checking column  "classes"
# FINISHED ALL!

# %%
data.isnull().sum().sort_values(ascending=False)
# Out:
# desc                          1135844
# title                           14533
# emp_title                        5806
# classes                             0
# revol_bal                           0
# fico_range_low                      0
# fico_range_high                     0
# inq_last_6mths                      0
# open_acc                            0
# pub_rec                             0
# revol_util                          0
# delinq_2yrs                         0
# total_acc                           0
# out_prncp                           0
# out_prncp_inv                       0
# recoveries                          0
# collection_recovery_fee             0
# last_pymnt_amnt                     0
# earliest_cr_line                    0
# addr_state                          0
# dti                                 0
# debt_settlement_flag                0
# purpose                             0
# pymnt_plan                          0
# issue_d                             0
# verification_status                 0
# annual_inc                          0
# home_ownership                      0
# emp_length                          0
# grade                               0
#                                ...
# num_tl_90g_dpd_24m                  0
# num_tl_op_past_12m                  0
# pct_tl_nvr_dlq                      0
# pub_rec_bankruptcies                0
# num_op_rev_tl                       0
# tax_liens                           0
# tot_hi_cred_lim                     0
# total_bal_ex_mort                   0
# total_il_high_credit_limit          0
# hardship_flag                       0
# disbursement_method                 0
# num_rev_accts                       0
# num_il_tl                           0
# application_type                    0
# bc_util                             0
# acc_now_delinq                      0
# tot_coll_amt                        0
# tot_cur_bal                         0
# acc_open_past_24mths                0
# avg_cur_bal                         0
# bc_open_to_buy                      0
# chargeoff_within_12_mths            0
# num_bc_tl                           0
# delinq_amnt                         0
# mort_acc                            0
# num_accts_ever_120_pd               0
# num_actv_bc_tl                      0
# num_actv_rev_tl                     0
# num_bc_sats                         0
# loan_amnt                           0
# Length: 72, dtype: int64

# %%
data['emp_title'].fillna(" . ", inplace= True)

# %%
data['title'].fillna(" . ", inplace= True)

# %%
data['desc'].fillna(" . ", inplace= True)

# %%
data.shape
# Out:
# (1210906, 72)

# %% [markdown]
# - WRITE A FUNCTION TO CHECK THE CORRELATION OF VALUES AND RETURN THEM AS TUPLES WITH THE CORRELATION IF ABOVE .55

# %% [markdown]
# ## Reviewing data types for our columns and making sure that they're as they should be

# %%
data.dtypes.value_counts()
# Out:
# float64    54
# object     17
# int64       1
# dtype: int64

# %%
object_cols = data.select_dtypes(include='object').columns

# %% [markdown]
# ### In order to feed the dates into my model, I need to convert the above 2 columns 'issue_d' and 'earliest_cr_line' to DateTime and then generating a new column for the difference. This difference is a proxy for their creditworthiness, or at least one element of the equation, in which the amount of history with creditors is available for analysis.

# %%
data['issue_d'].head()
# Out:
# 0    Dec-2015
# 1    Dec-2015
# 2    Dec-2015
# 4    Dec-2015
# 5    Dec-2015
# Name: issue_d, dtype: object

# %%
data['issue_d'] = pd.to_datetime(data['issue_d'])

# %%
data['earliest_cr_line'].head()
# Out:
# 0    Aug-2003
# 1    Dec-1999
# 2    Aug-2000
# 4    Jun-1998
# 5    Oct-1987
# Name: earliest_cr_line, dtype: object

# %%
data['earliest_cr_line'] = pd.to_datetime(data['earliest_cr_line'])

# %%
# taking the difference of the 2 columns to create length of credit history
data['credit_length_days'] = data['issue_d'] - data['earliest_cr_line']

# %%
#extracting just the days out of the timedate format
data['credit_length_days'] = data['credit_length_days'].dt.days

# %%
#verifying the output
data['credit_length_days'].head()
# Out:
# 0     4505
# 1     5844
# 2     5600
# 4     6392
# 5    10288
# Name: credit_length_days, dtype: int64

# %% [markdown]
# As seen in the cell above, we need to strip out " days" from each piece of information to convert the datatype from timedelta64 to something that can be interpreted by the classification models.

# %%
data.isnull().sum().sort_values(ascending=False)
# Out:
# credit_length_days            0
# last_fico_range_low           0
# delinq_2yrs                   0
# earliest_cr_line              0
# fico_range_low                0
# fico_range_high               0
# inq_last_6mths                0
# open_acc                      0
# pub_rec                       0
# revol_bal                     0
# revol_util                    0
# total_acc                     0
# out_prncp                     0
# out_prncp_inv                 0
# recoveries                    0
# collection_recovery_fee       0
# last_pymnt_amnt               0
# dti                           0
# addr_state                    0
# title                         0
# emp_title                     0
# funded_amnt                   0
# funded_amnt_inv               0
# term                          0
# int_rate                      0
# installment                   0
# grade                         0
# emp_length                    0
# purpose                       0
# home_ownership                0
#                              ..
# num_tl_op_past_12m            0
# pct_tl_nvr_dlq                0
# percent_bc_gt_75              0
# pub_rec_bankruptcies          0
# tax_liens                     0
# tot_hi_cred_lim               0
# total_bal_ex_mort             0
# total_il_high_credit_limit    0
# hardship_flag                 0
# disbursement_method           0
# debt_settlement_flag          0
# num_rev_accts                 0
# num_op_rev_tl                 0
# num_il_tl                     0
# bc_util                       0
# acc_now_delinq                0
# tot_coll_amt                  0
# tot_cur_bal                   0
# acc_open_past_24mths          0
# avg_cur_bal                   0
# bc_open_to_buy                0
# chargeoff_within_12_mths      0
# num_bc_tl                     0
# delinq_amnt                   0
# mort_acc                      0
# num_accts_ever_120_pd         0
# num_actv_bc_tl                0
# num_actv_rev_tl               0
# num_bc_sats                   0
# loan_amnt                     0
# Length: 73, dtype: int64

# %% [markdown]
# ## Now that we have no missing values in our dataset we can move on to the next steps. In the next notebook, we continue with Feature Engineering and some additional EDA. In order to make this process as smooth as possible, I am splitting up the notebooks and exporting the current dataset to a csv file to be loaded in the next notebook.

# %%
data.to_csv('./cleaned_af.csv', index=False)
