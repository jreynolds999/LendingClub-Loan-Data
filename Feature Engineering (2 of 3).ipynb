# %% [markdown]
# # Predicting Bad Loans with Machine Learning - Part 2: Feature Engineering

# %% [markdown]
# ### Content List
# #### Imports
# ####

# %% [markdown]
# Feature Engineering Steps:
# - Brainstorming or testing features.
# - Deciding what features to create.
# - Creating features.
# - Checking how the features work with your model.
# - Improving features (if needed).

# %% [markdown]
# ### Imports
# Similar imports as in Part 1

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import math

# %%
data_ = pd.read_csv('./cleaned_af.csv')

# %%
data = data_

# %% [markdown]
# ### Check data types for columns
# This is an important step as we need to have a clear idea of which how many object columns remain as we need to get them into an interpretable format.

# %%
data.dtypes.value_counts()
# Out:
# float64    54
# object     17
# int64       2
# dtype: int64

# %% [markdown]
# With 19 object columns present, we will need to consider multiple options for manipulating the data types. Most likely we will use a combination of ordinal rankings, one-hot dummy encoding, binarizing two-value features and taking the length of user submitted text columns.

# %%
object_cols = data.select_dtypes(include='object').columns
object_cols
# Out:
# Index(['term', 'grade', 'emp_title', 'emp_length', 'home_ownership',
#        'verification_status', 'issue_d', 'pymnt_plan', 'desc', 'purpose',
#        'title', 'addr_state', 'earliest_cr_line', 'application_type',
#        'hardship_flag', 'disbursement_method', 'debt_settlement_flag'],
#       dtype='object')

# %% [markdown]
# The following features will be binarized: term, verification_status, pyment_plan, application_type, hardship_flag, disbursement_method and debt_settlement_flag.
#
# The following features will be one-hot encoded: home_ownership, purpose and addr_state.
#
# The following features will be encoded with ordinal rank: emp_length and grade.
#
# The text columns of desc, emp_title and title will each be measured by length, then combined into one feature for potential Natural Language Processing work.
#
# The remaining text columns of issue_d and earliest_cr_line will be converted into DateTime format, then create a new column from their difference that will be converted into an integer.

# %%
data.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'emp_title', 'emp_length', 'home_ownership',
#        'annual_inc', 'verification_status', 'issue_d', 'pymnt_plan', 'desc',
#        'purpose', 'title', 'addr_state', 'dti', 'delinq_2yrs',
#        'earliest_cr_line', 'fico_range_low', 'fico_range_high',
#        'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util',
#        'total_acc', 'out_prncp', 'out_prncp_inv', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_amnt', 'last_fico_range_high',
#        'last_fico_range_low', 'collections_12_mths_ex_med', 'application_type',
#        'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'acc_open_past_24mths',
#        'avg_cur_bal', 'bc_open_to_buy', 'bc_util', 'chargeoff_within_12_mths',
#        'delinq_amnt', 'mort_acc', 'num_accts_ever_120_pd', 'num_actv_bc_tl',
#        'num_actv_rev_tl', 'num_bc_sats', 'num_bc_tl', 'num_il_tl',
#        'num_op_rev_tl', 'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats',
#        'num_tl_30dpd', 'num_tl_90g_dpd_24m', 'num_tl_op_past_12m',
#        'pct_tl_nvr_dlq', 'percent_bc_gt_75', 'pub_rec_bankruptcies',
#        'tax_liens', 'tot_hi_cred_lim', 'total_bal_ex_mort',
#        'total_il_high_credit_limit', 'hardship_flag', 'disbursement_method',
#        'debt_settlement_flag', 'classes', 'credit_length_days'],
#       dtype='object')

# %% [markdown]
# ### User-Submitted Text Features

# %% [markdown]
# #### build an aggregate column of all text input

# %%
desc_length = []

[desc_length.append(len(i)) for i in data.desc]
    
data["desc_length"]= desc_length

# %%
data['desc_length'].head()
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    3
# Name: desc_length, dtype: int64

# %%
data['all_text'] = data['desc'] + " " + data['emp_title'] + " " + data['title']

# %%
data['all_text'].head()
# Out:
# 0                  .  leadman Debt consolidation
# 1                           .  Engineer Business
# 2                            .  truck driver  .
# 3          .  Contract Specialist Major purchase
# 4     .  Veterinary Tecnician Debt consolidation
# Name: all_text, dtype: object

# %% [markdown]
# #### Using List Comprehension, measure the lengths of each item dealing with user text input and return that as a new column

# %%
all_text_length = [len(i) for i in data['all_text']]
    
data["all_text_length"] = all_text_length

# %%
data['all_text_length'].value_counts()
# Out:
# 38      60580
# 30      57492
# 39      56927
# 37      55074
# 35      51277
# 33      49551
# 40      46482
# 41      46009
# 36      44413
# 42      44295
# 43      41064
# 44      38316
# 32      37271
# 31      36667
# 34      35612
# 45      35335
# 28      35051
# 46      29577
# 47      28637
# 29      27050
# 26      23967
# 48      23175
# 49      19246
# 50      18970
# 25      16569
# 51      15563
# 27      14842
# 52      14439
# 53      11567
# 54      10114
#         ...
# 781         1
# 784         1
# 1664        1
# 788         1
# 790         1
# 792         1
# 798         1
# 799         1
# 801         1
# 803         1
# 1779        1
# 755         1
# 753         1
# 751         1
# 1714        1
# 3779        1
# 1747        1
# 730         1
# 737         1
# 739         1
# 741         1
# 742         1
# 743         1
# 744         1
# 745         1
# 746         1
# 747         1
# 748         1
# 750         1
# 1024        1
# Name: all_text_length, Length: 973, dtype: int64

# %%
data.emp_title.head()
# Out:
# 0                 leadman
# 1                Engineer
# 2            truck driver
# 3     Contract Specialist
# 4    Veterinary Tecnician
# Name: emp_title, dtype: object

# %%
desc_length = [len(i) for i in data.desc]
    
data["desc_length"]= desc_length

# %%
emp_title_length = [len(i) for i in data.emp_title]

data["emp_title_length"] = emp_title_length

# %%
title_length = [len(i) for i in data.title]
    
data["title_length"] = title_length

# %% [markdown]
# ### Ordinal Rankings: converting grade G:1 to A:7

# %%
#building a dictionary of values to identify and replace
length_dict = {'A':7,
        'B': 6,               
        'C': 5,
        'D': 4,
        'E': 3,
        'F': 2,
        'G': 1,}
data['grade'].replace(length_dict, inplace=True)

# %%
data['grade'].head()
# Out:
# 0    5
# 1    5
# 2    6
# 3    2
# 4    5
# Name: grade, dtype: int64

# %% [markdown]
# Next, employment length needs to be converted from strings to integers that represent the ordinal ranking of the values. First we need to convert less than 1 years to 0, then more than 10 years to 10. Although this is not a perfectly representative scale, it is good enough for our purposes.

# %%
#building a dictionary of values to identify and replace
length_dict = {'10+ years':10,
        '2 years': 2,
        '< 1 year': 0,
        '3 years': 3,
        '1 year': 1,
        '5 years': 5,
        '4 years': 4,
        '6 years': 6,
        '8 years': 8,
        '7 years': 7,
        '9 years': 9}
data['emp_length'].replace(length_dict, inplace=True)

# %%
data['emp_length'].value_counts()
# Out:
# 10    428216
# 2     115916
# 3     102514
# 0     102306
# 1      84143
# 5      79155
# 4      75762
# 6      59046
# 8      58333
# 7      56600
# 9      48915
# Name: emp_length, dtype: int64

# %% [markdown]
# VISUALIZE WITH SCATTERPLOT

# %%
data['emp_length'].value_counts(normalize=True)
# Out:
# 10    0.353633
# 2     0.095727
# 3     0.084659
# 0     0.084487
# 1     0.069488
# 5     0.065368
# 4     0.062566
# 6     0.048762
# 8     0.048173
# 7     0.046742
# 9     0.040395
# Name: emp_length, dtype: float64

# %%
# Find the mean employment length of people whose loans did or did not succeed.

data.groupby(by='classes')['emp_length'].mean()
# Out:
# classes
# 0    5.860851
# 1    6.033932
# Name: emp_length, dtype: float64

# %% [markdown]
# ### one hot encoding values for columns
# - purpose
# - verification_status
# - addr_state
# - pymnt_plan
# - initial_list_status
# - application_type
# - hardship_flag
# - disbursement_method
# - debt_settlement_flag

# %%
## all remaining object cols
object_cols
# Out:
# Index(['term', 'grade', 'emp_title', 'emp_length', 'home_ownership',
#        'verification_status', 'issue_d', 'pymnt_plan', 'desc', 'purpose',
#        'title', 'addr_state', 'earliest_cr_line', 'application_type',
#        'hardship_flag', 'disbursement_method', 'debt_settlement_flag'],
#       dtype='object')

# %%
data['term'].head()
# Out:
# 0     36 months
# 1     36 months
# 2     60 months
# 3     60 months
# 4     36 months
# Name: term, dtype: object

# %% [markdown]
# #### Purpose

# %%
data['purpose'].value_counts()
# Out:
# debt_consolidation    710586
# credit_card           270419
# home_improvement       76917
# other                  66739
# major_purchase         25060
# medical                13252
# small_business         12448
# car                    11737
# moving                  8085
# vacation                7788
# house                   6281
# wedding                  848
# renewable_energy         746
# Name: purpose, dtype: int64

# %%
data.groupby(by='classes')['purpose'].value_counts(normalize= True)
# Out:
# classes  purpose
# 0        debt_consolidation    0.617561
#          credit_card           0.188380
#          other                 0.059608
#          home_improvement      0.057523
#          major_purchase        0.020580
#          small_business        0.015711
#          medical               0.011843
#          moving                0.007896
#          car                   0.007400
#          vacation              0.006299
#          house                 0.005974
#          renewable_energy      0.000744
#          wedding               0.000481
# 1        debt_consolidation    0.578500
#          credit_card           0.232778
#          home_improvement      0.065144
#          other                 0.053899
#          major_purchase        0.020726
#          medical               0.010701
#          car                   0.010313
#          small_business        0.008810
#          vacation              0.006467
#          moving                0.006347
#          house                 0.004974
#          wedding               0.000760
#          renewable_energy      0.000581
# Name: purpose, dtype: float64

# %%
# how to better visualize these representations?

# %%
one_hot = ['purpose', 'term',
'verification_status',
'pymnt_plan',
'application_type',
'hardship_flag', 'addr_state',
'disbursement_method', 
'debt_settlement_flag', 'home_ownership']

# %%
data = pd.get_dummies(data= data, columns = one_hot, drop_first=True)

# %%
data.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'int_rate',
#        'installment', 'grade', 'emp_title', 'emp_length', 'annual_inc',
#        'issue_d',
#        ...
#        'addr_state_WI', 'addr_state_WV', 'addr_state_WY',
#        'disbursement_method_DirectPay', 'debt_settlement_flag_Y',
#        'home_ownership_MORTGAGE', 'home_ownership_NONE',
#        'home_ownership_OTHER', 'home_ownership_OWN', 'home_ownership_RENT'],
#       dtype='object', length=143)

# %% [markdown]
# # Preprocessing of Text Feature
# - take the entire list of words in all_text and convert to 2 separate corpus based on whether they are associated with 1 or 0 for loan status

# %% [markdown]
# ### TF-IDF on data['all_text']

# %% [markdown]
# ### CountVectorizer word counter function

# %%
# # Function to count words in each df
# def word_counter(title_df,stop_list = []):
    
#     # Count Vectorize
#     cvec = CountVectorizer(stop_words = stop_list, max_features=15)

#     # Transform the corpus
#     X_text = cvec.fit_transform(title_df['Post Text'])

#     # Converts text to array form
#     X_text = pd.DataFrame(X_text.toarray(), columns= cvec.get_feature_names())

#     # See word counts
#     word_counts = X_text.sum().sort_values(0, ascending=False)
    
#     return word_counts

# %% [markdown]
# #### Interaction Columns

# %%
dataCorr = data.corr(method='pearson')
dataCorr = dataCorr[abs(dataCorr) >= 0.8].stack().reset_index()
dataCorr = dataCorr[dataCorr['level_0'].astype(str)!=dataCorr['level_1'].astype(str)]

# %%
# filtering out lower/upper triangular duplicates 
dataCorr['ordered-cols'] = dataCorr.apply(lambda x: '-'.join(sorted([x['level_0'],x['level_1']])),axis=1)
dataCorr = dataCorr.drop_duplicates(['ordered-cols'])
dataCorr.drop(['ordered-cols'], axis=1, inplace=True)

# %%
dataCorr = pd.DataFrame(dataCorr)

dataCorr.columns=['Initial', 'Secondary', 'Corr_Values']
#generate absolute value of corr values
dataCorr['Abs_Corr_Values'] = abs(dataCorr['Corr_Values'])
# initial_cols = list(dataCorr['Initial'])

# secondary_cols = list(dataCorr['Secondary'])

# %%
dataCorr = dataCorr.sort_values(by= 'Abs_Corr_Values', ascending = False)
dataCorr = dataCorr.iloc[6:]
dataCorr

# %%
for i,j in zip(dataCorr['Initial'], dataCorr['Secondary']):
    name = i + '*' + j  
    data[name] = data[i] * data[j]
    print(name)
# Out:
# desc_length*all_text_length
# num_actv_rev_tl*num_rev_tl_bal_gt_0
# tot_cur_bal*tot_hi_cred_lim
# recoveries*collection_recovery_fee
# int_rate*grade
# funded_amnt*installment
# loan_amnt*installment
# funded_amnt_inv*installment
# total_bal_ex_mort*total_il_high_credit_limit
# pymnt_plan_y*hardship_flag_Y
# revol_util*bc_util
# bc_util*percent_bc_gt_75
# tot_cur_bal*avg_cur_bal
# num_bc_tl*num_rev_accts
# last_fico_range_high*last_fico_range_low
# open_acc*num_op_rev_tl
# num_op_rev_tl*num_sats
# num_actv_bc_tl*num_bc_sats
# home_ownership_MORTGAGE*home_ownership_RENT
# num_actv_bc_tl*num_actv_rev_tl
# avg_cur_bal*tot_hi_cred_lim
# num_actv_bc_tl*num_rev_tl_bal_gt_0

# %%
#all of the values in this column are 0 since they are non-overlapping binary values
data.drop(columns = ['home_ownership_MORTGAGE*home_ownership_RENT'], inplace= True)

# %%
data.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  int_rate  installment  grade  \
# 0     3600.0       3600.0           3600.0     13.99       123.03      5
# 1    24700.0      24700.0          24700.0     11.99       820.28      5
# 2    20000.0      20000.0          20000.0     10.78       432.66      6
# 3    10400.0      10400.0          10400.0     22.45       289.91      2
# 4    11950.0      11950.0          11950.0     13.44       405.18      5
#
#               emp_title  emp_length  annual_inc     issue_d  ...  \
# 0               leadman          10     55000.0  2015-12-01  ...
# 1              Engineer          10     65000.0  2015-12-01  ...
# 2          truck driver          10     63000.0  2015-12-01  ...
# 3   Contract Specialist           3    104433.0  2015-12-01  ...
# 4  Veterinary Tecnician           4     34000.0  2015-12-01  ...
#
#   bc_util*percent_bc_gt_75 tot_cur_bal*avg_cur_bal  num_bc_tl*num_rev_accts  \
# 0                     0.00            2.999658e+09                     45.0
# 1                   208.67            1.989386e+09                    459.0
# 2                  2795.00            5.997713e+09                     28.0
# 3                  4650.00            9.170344e+09                    171.0
# 4                  9100.00            3.276288e+07                      8.0
#
#    last_fico_range_high*last_fico_range_low open_acc*num_op_rev_tl  \
# 0                                  315840.0                   28.0
# 1                                  485805.0                  440.0
# 2                                  492800.0                   24.0
# 3                                  492800.0                   84.0
# 4                                  573045.0                   20.0
#
#    num_op_rev_tl*num_sats  num_actv_bc_tl*num_bc_sats  \
# 0                    28.0                         4.0
# 1                   440.0                        65.0
# 2                    24.0                         4.0
# 3                    84.0                        20.0
# 4                    20.0                         4.0
#
#    num_actv_bc_tl*num_actv_rev_tl  avg_cur_bal*tot_hi_cred_lim  \
# 0                             8.0                 3.685813e+09
# 1                            25.0                 3.056327e+09
# 2                             6.0                 6.905722e+09
# 3                            24.0                 1.215147e+10
# 4                             6.0                 4.326400e+07
#
#    num_actv_bc_tl*num_rev_tl_bal_gt_0
# 0                                 8.0
# 1                                25.0
# 2                                 6.0
# 3                                24.0
# 4                                 6.0
#
# [5 rows x 164 columns]

# %%
data.shape
# Out:
# (1210906, 164)

# %%
data.corr()
# Out:
#                                               loan_amnt  funded_amnt  \
# loan_amnt                                      1.000000     0.999999
# funded_amnt                                    0.999999     1.000000
# funded_amnt_inv                                0.999994     0.999994
# int_rate                                       0.139270     0.139269
# installment                                    0.952266     0.952267
# grade                                         -0.138890    -0.138888
# emp_length                                     0.082787     0.082788
# annual_inc                                     0.302155     0.302154
# dti                                            0.028150     0.028150
# delinq_2yrs                                   -0.007105    -0.007105
# fico_range_low                                 0.111066     0.111066
# fico_range_high                                0.111065     0.111065
# inq_last_6mths                                -0.014387    -0.014390
# open_acc                                       0.173229     0.173227
# pub_rec                                       -0.064684    -0.064684
# revol_bal                                      0.313839     0.313838
# revol_util                                     0.104817     0.104816
# total_acc                                      0.200467     0.200465
# out_prncp                                      0.109540     0.109541
# out_prncp_inv                                  0.109540     0.109540
# recoveries                                     0.186126     0.186123
# collection_recovery_fee                        0.180621     0.180621
# last_pymnt_amnt                                0.489267     0.489268
# last_fico_range_high                           0.047629     0.047629
# last_fico_range_low                            0.044943     0.044943
# collections_12_mths_ex_med                    -0.020518    -0.020518
# acc_now_delinq                                -0.000047    -0.000047
# tot_coll_amt                                  -0.003208    -0.003208
# tot_cur_bal                                    0.309031     0.309030
# acc_open_past_24mths                           0.005276     0.005275
# ...                                                 ...          ...
# addr_state_WV                                 -0.001676    -0.001676
# addr_state_WY                                  0.002578     0.002578
# disbursement_method_DirectPay                  0.006468     0.006468
# debt_settlement_flag_Y                         0.017035     0.017035
# home_ownership_MORTGAGE                        0.172558     0.172557
# home_ownership_NONE                            0.000041     0.000041
# home_ownership_OTHER                          -0.000605    -0.000605
# home_ownership_OWN                            -0.015694    -0.015694
# home_ownership_RENT                           -0.166470    -0.166469
# desc_length*all_text_length                    0.008245     0.008245
# num_actv_rev_tl*num_rev_tl_bal_gt_0            0.126330     0.126330
# tot_cur_bal*tot_hi_cred_lim                    0.185019     0.185019
# recoveries*collection_recovery_fee             0.109221     0.109221
# int_rate*grade                                -0.001815    -0.001814
# funded_amnt*installment                        0.940908     0.940909
# loan_amnt*installment                          0.940909     0.940909
# funded_amnt_inv*installment                    0.940919     0.940919
# total_bal_ex_mort*total_il_high_credit_limit   0.113851     0.113848
# pymnt_plan_y*hardship_flag_Y                   0.010070     0.010070
# revol_util*bc_util                             0.078181     0.078181
# bc_util*percent_bc_gt_75                       0.014846     0.014847
# tot_cur_bal*avg_cur_bal                        0.168176     0.168177
# num_bc_tl*num_rev_accts                        0.153768     0.153767
# last_fico_range_high*last_fico_range_low       0.051510     0.051511
# open_acc*num_op_rev_tl                         0.151051     0.151050
# num_op_rev_tl*num_sats                         0.151353     0.151351
# num_actv_bc_tl*num_bc_sats                     0.175135     0.175135
# num_actv_bc_tl*num_actv_rev_tl                 0.152968     0.152968
# avg_cur_bal*tot_hi_cred_lim                    0.166044     0.166044
# num_actv_bc_tl*num_rev_tl_bal_gt_0             0.153694     0.153694
#
#                                               funded_amnt_inv  int_rate  \
# loan_amnt                                            0.999994  0.139270
# funded_amnt                                          0.999994  0.139269
# funded_amnt_inv                                      1.000000  0.139251
# int_rate                                             0.139251  1.000000
# installment                                          0.952221  0.151851
# grade                                               -0.138861 -0.954909
# emp_length                                           0.082804 -0.008513
# annual_inc                                           0.302183 -0.075934
# dti                                                  0.028086  0.164399
# delinq_2yrs                                         -0.007125  0.043206
# fico_range_low                                       0.111151 -0.389911
# fico_range_high                                      0.111150 -0.389908
# inq_last_6mths                                      -0.014402  0.220817
# open_acc                                             0.173217 -0.004234
# pub_rec                                             -0.064687  0.051333
# revol_bal                                            0.313823 -0.031564
# revol_util                                           0.104760  0.231020
# total_acc                                            0.200456 -0.043409
# out_prncp                                            0.109592  0.070292
# out_prncp_inv                                        0.109592  0.070292
# recoveries                                           0.186107  0.186637
# collection_recovery_fee                              0.180600  0.175292
# last_pymnt_amnt                                      0.489316  0.079088
# last_fico_range_high                                 0.047657 -0.349476
# last_fico_range_low                                  0.044968 -0.270823
# collections_12_mths_ex_med                          -0.020530  0.014645
# acc_now_delinq                                      -0.000062  0.016539
# tot_coll_amt                                        -0.003208  0.002434
# tot_cur_bal                                          0.309053 -0.084577
# acc_open_past_24mths                                 0.005257  0.193991
# ...                                                       ...       ...
# addr_state_WV                                       -0.001682 -0.000283
# addr_state_WY                                        0.002572 -0.000206
# disbursement_method_DirectPay                        0.006457  0.000426
# debt_settlement_flag_Y                               0.016992  0.065571
# home_ownership_MORTGAGE                              0.172573 -0.069250
# home_ownership_NONE                                  0.000042  0.002348
# home_ownership_OTHER                                -0.000612  0.002425
# home_ownership_OWN                                  -0.015689  0.004583
# home_ownership_RENT                                 -0.166488  0.067768
# desc_length*all_text_length                          0.008153  0.008991
# num_actv_rev_tl*num_rev_tl_bal_gt_0                  0.126303  0.080279
# tot_cur_bal*tot_hi_cred_lim                          0.185036 -0.053812
# recoveries*collection_recovery_fee                   0.109197  0.079478
# int_rate*grade                                      -0.001766  0.451844
# funded_amnt*installment                              0.940887  0.145767
# loan_amnt*installment                                0.940887  0.145768
# funded_amnt_inv*installment                          0.940903  0.145756
# total_bal_ex_mort*total_il_high_credit_limit         0.113854 -0.003183
# pymnt_plan_y*hardship_flag_Y                         0.010079  0.009903
# revol_util*bc_util                                   0.078128  0.241156
# bc_util*percent_bc_gt_75                             0.014803  0.243202
# tot_cur_bal*avg_cur_bal                              0.168193 -0.052347
# num_bc_tl*num_rev_accts                              0.153755 -0.054052
# last_fico_range_high*last_fico_range_low             0.051539 -0.332678
# open_acc*num_op_rev_tl                               0.151043 -0.000277
# num_op_rev_tl*num_sats                               0.151344 -0.000506
# num_actv_bc_tl*num_bc_sats                           0.175125 -0.001029
# num_actv_bc_tl*num_actv_rev_tl                       0.152948  0.052205
# avg_cur_bal*tot_hi_cred_lim                          0.166061 -0.056716
# num_actv_bc_tl*num_rev_tl_bal_gt_0                   0.153673  0.053368
#
#                                               installment     grade  \
# loan_amnt                                        0.952266 -0.138890
# funded_amnt                                      0.952267 -0.138888
# funded_amnt_inv                                  0.952221 -0.138861
# int_rate                                         0.151851 -0.954909
# installment                                      1.000000 -0.141801
# grade                                           -0.141801  1.000000
# emp_length                                       0.070435  0.008108
# annual_inc                                       0.293448  0.074031
# dti                                              0.030747 -0.167070
# delinq_2yrs                                      0.002150 -0.047904
# fico_range_low                                   0.061982  0.390875
# fico_range_high                                  0.061981  0.390872
# inq_last_6mths                                   0.009763 -0.217745
# open_acc                                         0.162914 -0.001603
# pub_rec                                         -0.053418 -0.058630
# revol_bal                                        0.302035  0.030428
# revol_util                                       0.122603 -0.227646
# total_acc                                        0.176541  0.037339
# out_prncp                                        0.094428 -0.049110
# out_prncp_inv                                    0.094421 -0.049110
# recoveries                                       0.166535 -0.193582
# collection_recovery_fee                          0.161601 -0.184025
# last_pymnt_amnt                                  0.427527 -0.074701
# last_fico_range_high                             0.034606  0.351699
# last_fico_range_low                              0.035306  0.272756
# collections_12_mths_ex_med                      -0.016875 -0.018473
# acc_now_delinq                                   0.002812 -0.020272
# tot_coll_amt                                    -0.002686 -0.002447
# tot_cur_bal                                      0.278472  0.083775
# acc_open_past_24mths                             0.019244 -0.199619
# ...                                                   ...       ...
# addr_state_WV                                   -0.004649 -0.000868
# addr_state_WY                                    0.001934  0.000215
# disbursement_method_DirectPay                    0.004940  0.002501
# debt_settlement_flag_Y                           0.011289 -0.072119
# home_ownership_MORTGAGE                          0.141050  0.069773
# home_ownership_NONE                              0.000777 -0.001431
# home_ownership_OTHER                             0.000356 -0.000872
# home_ownership_OWN                              -0.010617 -0.005485
# home_ownership_RENT                             -0.137486 -0.067815
# desc_length*all_text_length                      0.012397  0.012599
# num_actv_rev_tl*num_rev_tl_bal_gt_0              0.133545 -0.084583
# tot_cur_bal*tot_hi_cred_lim                      0.173695  0.052681
# recoveries*collection_recovery_fee               0.099542 -0.083411
# int_rate*grade                                   0.004821 -0.290120
# funded_amnt*installment                          0.960858 -0.140466
# loan_amnt*installment                            0.960858 -0.140467
# funded_amnt_inv*installment                      0.960844 -0.140450
# total_bal_ex_mort*total_il_high_credit_limit     0.108768  0.001562
# pymnt_plan_y*hardship_flag_Y                     0.009765 -0.007519
# revol_util*bc_util                               0.097040 -0.240145
# bc_util*percent_bc_gt_75                         0.033802 -0.244775
# tot_cur_bal*avg_cur_bal                          0.156970  0.051980
# num_bc_tl*num_rev_accts                          0.143661  0.052573
# last_fico_range_high*last_fico_range_low         0.038526  0.334643
# open_acc*num_op_rev_tl                           0.145822 -0.004201
# num_op_rev_tl*num_sats                           0.146060 -0.003865
# num_actv_bc_tl*num_bc_sats                       0.174919  0.000488
# num_actv_bc_tl*num_actv_rev_tl                   0.158183 -0.054029
# avg_cur_bal*tot_hi_cred_lim                      0.154809  0.056126
# num_actv_bc_tl*num_rev_tl_bal_gt_0               0.158914 -0.055011
#
#                                               emp_length  annual_inc  \
# loan_amnt                                       0.082787    0.302155
# funded_amnt                                     0.082788    0.302154
# funded_amnt_inv                                 0.082804    0.302183
# int_rate                                       -0.008513   -0.075934
# installment                                     0.070435    0.293448
# grade                                           0.008108    0.074031
# emp_length                                      1.000000    0.062960
# annual_inc                                      0.062960    1.000000
# dti                                             0.020588   -0.158502
# delinq_2yrs                                     0.019218    0.037949
# fico_range_low                                  0.022557    0.075268
# fico_range_high                                 0.022558    0.075268
# inq_last_6mths                                  0.002032    0.032948
# open_acc                                        0.040294    0.125059
# pub_rec                                         0.029482   -0.000811
# revol_bal                                       0.082632    0.280051
# revol_util                                      0.035109    0.032514
# total_acc                                       0.100853    0.167601
# out_prncp                                      -0.007988    0.019291
# out_prncp_inv                                  -0.007986    0.019292
# recoveries                                      0.010464    0.024821
# collection_recovery_fee                         0.010552    0.024999
# last_pymnt_amnt                                 0.054586    0.171898
# last_fico_range_high                            0.023215    0.065662
# last_fico_range_low                             0.027386    0.059142
# collections_12_mths_ex_med                     -0.008048   -0.004846
# acc_now_delinq                                  0.008431    0.012920
# tot_coll_amt                                    0.000005    0.000171
# tot_cur_bal                                     0.100130    0.387453
# acc_open_past_24mths                            0.022337    0.053896
# ...                                                  ...         ...
# addr_state_WV                                   0.006862   -0.006815
# addr_state_WY                                   0.000343   -0.002042
# disbursement_method_DirectPay                  -0.007453   -0.002521
# debt_settlement_flag_Y                          0.004584   -0.013624
# home_ownership_MORTGAGE                         0.180459    0.134733
# home_ownership_NONE                             0.001333   -0.001384
# home_ownership_OTHER                            0.000888   -0.001293
# home_ownership_OWN                              0.020741   -0.015279
# home_ownership_RENT                            -0.197249   -0.128104
# desc_length*all_text_length                    -0.001412   -0.005881
# num_actv_rev_tl*num_rev_tl_bal_gt_0             0.109369    0.068316
# tot_cur_bal*tot_hi_cred_lim                     0.044213    0.334437
# recoveries*collection_recovery_fee              0.009817    0.022665
# int_rate*grade                                 -0.011900   -0.077700
# funded_amnt*installment                         0.067804    0.305447
# loan_amnt*installment                           0.067803    0.305448
# funded_amnt_inv*installment                     0.067814    0.305467
# total_bal_ex_mort*total_il_high_credit_limit   -0.027975    0.187373
# pymnt_plan_y*hardship_flag_Y                   -0.000986    0.001552
# revol_util*bc_util                              0.032103    0.022599
# bc_util*percent_bc_gt_75                        0.027609   -0.015069
# tot_cur_bal*avg_cur_bal                         0.041184    0.310131
# num_bc_tl*num_rev_accts                         0.108443    0.100856
# last_fico_range_high*last_fico_range_low        0.025996    0.065746
# open_acc*num_op_rev_tl                          0.078450    0.093234
# num_op_rev_tl*num_sats                          0.078100    0.093166
# num_actv_bc_tl*num_bc_sats                      0.071720    0.105052
# num_actv_bc_tl*num_actv_rev_tl                  0.092986    0.087468
# avg_cur_bal*tot_hi_cred_lim                     0.042661    0.302166
# num_actv_bc_tl*num_rev_tl_bal_gt_0              0.094831    0.087221
#
#                                                    dti  delinq_2yrs  ...  \
# loan_amnt                                     0.028150    -0.007105  ...
# funded_amnt                                   0.028150    -0.007105  ...
# funded_amnt_inv                               0.028086    -0.007125  ...
# int_rate                                      0.164399     0.043206  ...
# installment                                   0.030747     0.002150  ...
# grade                                        -0.167070    -0.047904  ...
# emp_length                                    0.020588     0.019218  ...
# annual_inc                                   -0.158502     0.037949  ...
# dti                                           1.000000    -0.013396  ...
# delinq_2yrs                                  -0.013396     1.000000  ...
# fico_range_low                               -0.054395    -0.172050  ...
# fico_range_high                              -0.054398    -0.172048  ...
# inq_last_6mths                               -0.001297     0.026067  ...
# open_acc                                      0.257249     0.049215  ...
# pub_rec                                      -0.044929    -0.021425  ...
# revol_bal                                     0.122560    -0.029370  ...
# revol_util                                    0.157980    -0.011276  ...
# total_acc                                     0.200464     0.117186  ...
# out_prncp                                     0.014944     0.003301  ...
# out_prncp_inv                                 0.014941     0.003299  ...
# recoveries                                    0.053644     0.015788  ...
# collection_recovery_fee                       0.054210     0.016236  ...
# last_pymnt_amnt                              -0.013753    -0.021821  ...
# last_fico_range_high                         -0.083359    -0.071965  ...
# last_fico_range_low                          -0.049081    -0.035030  ...
# collections_12_mths_ex_med                   -0.006021     0.070766  ...
# acc_now_delinq                                0.002528     0.123954  ...
# tot_coll_amt                                 -0.003446    -0.000381  ...
# tot_cur_bal                                   0.009882     0.055661  ...
# acc_open_past_24mths                          0.137736    -0.056283  ...
# ...                                                ...          ...  ...
# addr_state_WV                                 0.010879     0.001044  ...
# addr_state_WY                                 0.010612    -0.000387  ...
# disbursement_method_DirectPay                 0.057387    -0.006180  ...
# debt_settlement_flag_Y                        0.042106     0.005778  ...
# home_ownership_MORTGAGE                       0.009534     0.042385  ...
# home_ownership_NONE                           0.002313     0.000338  ...
# home_ownership_OTHER                          0.001304    -0.001505  ...
# home_ownership_OWN                            0.011593     0.001766  ...
# home_ownership_RENT                          -0.017034    -0.044381  ...
# desc_length*all_text_length                  -0.009862    -0.010406  ...
# num_actv_rev_tl*num_rev_tl_bal_gt_0           0.188477    -0.007155  ...
# tot_cur_bal*tot_hi_cred_lim                  -0.024968     0.026919  ...
# recoveries*collection_recovery_fee            0.022453     0.007133  ...
# int_rate*grade                                0.087886     0.036579  ...
# funded_amnt*installment                       0.018765     0.000261  ...
# loan_amnt*installment                         0.018766     0.000261  ...
# funded_amnt_inv*installment                   0.018735     0.000251  ...
# total_bal_ex_mort*total_il_high_credit_limit  0.107706     0.026853  ...
# pymnt_plan_y*hardship_flag_Y                  0.003679     0.003560  ...
# revol_util*bc_util                            0.148315    -0.015282  ...
# bc_util*percent_bc_gt_75                      0.140474    -0.014558  ...
# tot_cur_bal*avg_cur_bal                      -0.068473     0.026477  ...
# num_bc_tl*num_rev_accts                       0.070976     0.042509  ...
# last_fico_range_high*last_fico_range_low     -0.072081    -0.061565  ...
# open_acc*num_op_rev_tl                        0.172828     0.017066  ...
# num_op_rev_tl*num_sats                        0.172877     0.016073  ...
# num_actv_bc_tl*num_bc_sats                    0.115816    -0.029869  ...
# num_actv_bc_tl*num_actv_rev_tl                0.162659    -0.022593  ...
# avg_cur_bal*tot_hi_cred_lim                  -0.063041     0.026482  ...
# num_actv_bc_tl*num_rev_tl_bal_gt_0            0.166127    -0.025418  ...
#
#                                               bc_util*percent_bc_gt_75  \
# loan_amnt                                                     0.014846
# funded_amnt                                                   0.014847
# funded_amnt_inv                                               0.014803
# int_rate                                                      0.243202
# installment                                                   0.033802
# grade                                                        -0.244775
# emp_length                                                    0.027609
# annual_inc                                                   -0.015069
# dti                                                           0.140474
# delinq_2yrs                                                  -0.014558
# fico_range_low                                               -0.382009
# fico_range_high                                              -0.382005
# inq_last_6mths                                               -0.073192
# open_acc                                                     -0.117126
# pub_rec                                                      -0.045300
# revol_bal                                                     0.118576
# revol_util                                                    0.744990
# total_acc                                                    -0.083258
# out_prncp                                                    -0.015268
# out_prncp_inv                                                -0.015267
# recoveries                                                    0.042816
# collection_recovery_fee                                       0.039743
# last_pymnt_amnt                                              -0.048751
# last_fico_range_high                                         -0.158303
# last_fico_range_low                                          -0.107369
# collections_12_mths_ex_med                                   -0.033764
# acc_now_delinq                                               -0.022851
# tot_coll_amt                                                 -0.006935
# tot_cur_bal                                                   0.026670
# acc_open_past_24mths                                         -0.176704
# ...                                                                ...
# addr_state_WV                                                 0.005228
# addr_state_WY                                                 0.005453
# disbursement_method_DirectPay                                -0.008188
# debt_settlement_flag_Y                                        0.022045
# home_ownership_MORTGAGE                                       0.013960
# home_ownership_NONE                                           0.003174
# home_ownership_OTHER                                          0.003827
# home_ownership_OWN                                           -0.038316
# home_ownership_RENT                                           0.009660
# desc_length*all_text_length                                   0.022162
# num_actv_rev_tl*num_rev_tl_bal_gt_0                           0.044998
# tot_cur_bal*tot_hi_cred_lim                                  -0.000355
# recoveries*collection_recovery_fee                            0.017580
# int_rate*grade                                                0.186524
# funded_amnt*installment                                       0.019953
# loan_amnt*installment                                         0.019953
# funded_amnt_inv*installment                                   0.019935
# total_bal_ex_mort*total_il_high_credit_limit                  0.010490
# pymnt_plan_y*hardship_flag_Y                                  0.001211
# revol_util*bc_util                                            0.869828
# bc_util*percent_bc_gt_75                                      1.000000
# tot_cur_bal*avg_cur_bal                                       0.022703
# num_bc_tl*num_rev_accts                                      -0.144321
# last_fico_range_high*last_fico_range_low                     -0.146339
# open_acc*num_op_rev_tl                                       -0.137619
# num_op_rev_tl*num_sats                                       -0.137746
# num_actv_bc_tl*num_bc_sats                                   -0.079894
# num_actv_bc_tl*num_actv_rev_tl                                0.009093
# avg_cur_bal*tot_hi_cred_lim                                   0.014916
# num_actv_bc_tl*num_rev_tl_bal_gt_0                            0.014423
#
#                                               tot_cur_bal*avg_cur_bal  \
# loan_amnt                                                    0.168176
# funded_amnt                                                  0.168177
# funded_amnt_inv                                              0.168193
# int_rate                                                    -0.052347
# installment                                                  0.156970
# grade                                                        0.051980
# emp_length                                                   0.041184
# annual_inc                                                   0.310131
# dti                                                         -0.068473
# delinq_2yrs                                                  0.026477
# fico_range_low                                               0.080792
# fico_range_high                                              0.080793
# inq_last_6mths                                               0.000176
# open_acc                                                    -0.006800
# pub_rec                                                     -0.027529
# revol_bal                                                    0.369693
# revol_util                                                   0.057323
# total_acc                                                    0.063480
# out_prncp                                                    0.003484
# out_prncp_inv                                                0.003486
# recoveries                                                  -0.002884
# collection_recovery_fee                                     -0.002598
# last_pymnt_amnt                                              0.123986
# last_fico_range_high                                         0.065279
# last_fico_range_low                                          0.057770
# collections_12_mths_ex_med                                  -0.007966
# acc_now_delinq                                               0.012146
# tot_coll_amt                                                -0.001069
# tot_cur_bal                                                  0.720597
# acc_open_past_24mths                                        -0.019854
# ...                                                               ...
# addr_state_WV                                               -0.006415
# addr_state_WY                                               -0.000358
# disbursement_method_DirectPay                                0.002931
# debt_settlement_flag_Y                                      -0.014441
# home_ownership_MORTGAGE                                      0.212885
# home_ownership_NONE                                         -0.000740
# home_ownership_OTHER                                        -0.000734
# home_ownership_OWN                                          -0.014231
# home_ownership_RENT                                         -0.208638
# desc_length*all_text_length                                 -0.000923
# num_actv_rev_tl*num_rev_tl_bal_gt_0                         -0.034683
# tot_cur_bal*tot_hi_cred_lim                                  0.890048
# recoveries*collection_recovery_fee                           0.007055
# int_rate*grade                                              -0.047086
# funded_amnt*installment                                      0.172108
# loan_amnt*installment                                        0.172108
# funded_amnt_inv*installment                                  0.172120
# total_bal_ex_mort*total_il_high_credit_limit                 0.214634
# pymnt_plan_y*hardship_flag_Y                                -0.000057
# revol_util*bc_util                                           0.051183
# bc_util*percent_bc_gt_75                                     0.022703
# tot_cur_bal*avg_cur_bal                                      1.000000
# num_bc_tl*num_rev_accts                                     -0.001919
# last_fico_range_high*last_fico_range_low                     0.064572
# open_acc*num_op_rev_tl                                      -0.030877
# num_op_rev_tl*num_sats                                      -0.030964
# num_actv_bc_tl*num_bc_sats                                  -0.012297
# num_actv_bc_tl*num_actv_rev_tl                              -0.024076
# avg_cur_bal*tot_hi_cred_lim                                  0.973196
# num_actv_bc_tl*num_rev_tl_bal_gt_0                          -0.025400
#
#                                               num_bc_tl*num_rev_accts  \
# loan_amnt                                                    0.153768
# funded_amnt                                                  0.153767
# funded_amnt_inv                                              0.153755
# int_rate                                                    -0.054052
# installment                                                  0.143661
# grade                                                        0.052573
# emp_length                                                   0.108443
# annual_inc                                                   0.100856
# dti                                                          0.070976
# delinq_2yrs                                                  0.042509
# fico_range_low                                               0.041271
# fico_range_high                                              0.041271
# inq_last_6mths                                               0.140378
# open_acc                                                     0.550207
# pub_rec                                                      0.003091
# revol_bal                                                    0.197172
# revol_util                                                  -0.143209
# total_acc                                                    0.657516
# out_prncp                                                   -0.009106
# out_prncp_inv                                               -0.009109
# recoveries                                                   0.025220
# collection_recovery_fee                                      0.024599
# last_pymnt_amnt                                              0.081929
# last_fico_range_high                                         0.051919
# last_fico_range_low                                          0.054656
# collections_12_mths_ex_med                                  -0.005437
# acc_now_delinq                                               0.017700
# tot_coll_amt                                                 0.003013
# tot_cur_bal                                                  0.117936
# acc_open_past_24mths                                         0.318796
# ...                                                               ...
# addr_state_WV                                                0.001850
# addr_state_WY                                               -0.004315
# disbursement_method_DirectPay                                0.005282
# debt_settlement_flag_Y                                       0.009075
# home_ownership_MORTGAGE                                      0.084087
# home_ownership_NONE                                          0.000149
# home_ownership_OTHER                                         0.000471
# home_ownership_OWN                                           0.029833
# home_ownership_RENT                                         -0.104468
# desc_length*all_text_length                                  0.011201
# num_actv_rev_tl*num_rev_tl_bal_gt_0                          0.490202
# tot_cur_bal*tot_hi_cred_lim                                  0.071098
# recoveries*collection_recovery_fee                           0.018139
# int_rate*grade                                              -0.051269
# funded_amnt*installment                                      0.137900
# loan_amnt*installment                                        0.137900
# funded_amnt_inv*installment                                  0.137894
# total_bal_ex_mort*total_il_high_credit_limit                 0.035691
# pymnt_plan_y*hardship_flag_Y                                -0.002889
# revol_util*bc_util                                          -0.150492
# bc_util*percent_bc_gt_75                                    -0.144321
# tot_cur_bal*avg_cur_bal                                     -0.001919
# num_bc_tl*num_rev_accts                                      1.000000
# last_fico_range_high*last_fico_range_low                     0.056034
# open_acc*num_op_rev_tl                                       0.670451
# num_op_rev_tl*num_sats                                       0.668331
# num_actv_bc_tl*num_bc_sats                                   0.591021
# num_actv_bc_tl*num_actv_rev_tl                               0.522777
# avg_cur_bal*tot_hi_cred_lim                                  0.003548
# num_actv_bc_tl*num_rev_tl_bal_gt_0                           0.523269
#
#                                               last_fico_range_high*last_fico_range_low  \
# loan_amnt                                                                     0.051510
# funded_amnt                                                                   0.051511
# funded_amnt_inv                                                               0.051539
# int_rate                                                                     -0.332678
# installment                                                                   0.038526
# grade                                                                         0.334643
# emp_length                                                                    0.025996
# annual_inc                                                                    0.065746
# dti                                                                          -0.072081
# delinq_2yrs                                                                  -0.061565
# fico_range_low                                                                0.321410
# fico_range_high                                                               0.321410
# inq_last_6mths                                                               -0.097374
# open_acc                                                                      0.012533
# pub_rec                                                                      -0.060229
# revol_bal                                                                     0.061501
# revol_util                                                                   -0.144445
# total_acc                                                                     0.070322
# out_prncp                                                                    -0.067593
# out_prncp_inv                                                                -0.067587
# recoveries                                                                   -0.283252
# collection_recovery_fee                                                      -0.272601
# last_pymnt_amnt                                                               0.280321
# last_fico_range_high                                                          0.959507
# last_fico_range_low                                                           0.948114
# collections_12_mths_ex_med                                                   -0.028657
# acc_now_delinq                                                               -0.005897
# tot_coll_amt                                                                 -0.002471
# tot_cur_bal                                                                   0.114725
# acc_open_past_24mths                                                         -0.128741
# ...                                                                                ...
# addr_state_WV                                                                 0.005135
# addr_state_WY                                                                 0.004140
# disbursement_method_DirectPay                                                 0.006486
# debt_settlement_flag_Y                                                       -0.151714
# home_ownership_MORTGAGE                                                       0.106907
# home_ownership_NONE                                                           0.000272
# home_ownership_OTHER                                                         -0.000557
# home_ownership_OWN                                                           -0.002362
# home_ownership_RENT                                                          -0.107762
# desc_length*all_text_length                                                   0.013100
# num_actv_rev_tl*num_rev_tl_bal_gt_0                                          -0.075530
# tot_cur_bal*tot_hi_cred_lim                                                   0.063698
# recoveries*collection_recovery_fee                                           -0.082229
# int_rate*grade                                                               -0.201173
# funded_amnt*installment                                                       0.041173
# loan_amnt*installment                                                         0.041172
# funded_amnt_inv*installment                                                   0.041188
# total_bal_ex_mort*total_il_high_credit_limit                                  0.014639
# pymnt_plan_y*hardship_flag_Y                                                 -0.006897
# revol_util*bc_util                                                           -0.145110
# bc_util*percent_bc_gt_75                                                     -0.146339
# tot_cur_bal*avg_cur_bal                                                       0.064572
# num_bc_tl*num_rev_accts                                                       0.056034
# last_fico_range_high*last_fico_range_low                                      1.000000
# open_acc*num_op_rev_tl                                                        0.005637
# num_op_rev_tl*num_sats                                                        0.005941
# num_actv_bc_tl*num_bc_sats                                                   -0.014745
# num_actv_bc_tl*num_actv_rev_tl                                               -0.056023
# avg_cur_bal*tot_hi_cred_lim                                                   0.066724
# num_actv_bc_tl*num_rev_tl_bal_gt_0                                           -0.056897
#
#                                               open_acc*num_op_rev_tl  \
# loan_amnt                                                   0.151051
# funded_amnt                                                 0.151050
# funded_amnt_inv                                             0.151043
# int_rate                                                   -0.000277
# installment                                                 0.145822
# grade                                                      -0.004201
# emp_length                                                  0.078450
# annual_inc                                                  0.093234
# dti                                                         0.172828
# delinq_2yrs                                                 0.017066
# fico_range_low                                              0.023832
# fico_range_high                                             0.023831
# inq_last_6mths                                              0.138668
# open_acc                                                    0.870318
# pub_rec                                                    -0.010031
# revol_bal                                                   0.210132
# revol_util                                                 -0.169239
# total_acc                                                   0.591362
# out_prncp                                                   0.010254
# out_prncp_inv                                               0.010250
# recoveries                                                  0.036944
# collection_recovery_fee                                     0.037842
# last_pymnt_amnt                                             0.070698
# last_fico_range_high                                       -0.000295
# last_fico_range_low                                         0.011555
# collections_12_mths_ex_med                                  0.004341
# acc_now_delinq                                              0.014407
# tot_coll_amt                                                0.000383
# tot_cur_bal                                                 0.139785
# acc_open_past_24mths                                        0.463026
# ...                                                              ...
# addr_state_WV                                              -0.001195
# addr_state_WY                                              -0.007286
# disbursement_method_DirectPay                               0.019736
# debt_settlement_flag_Y                                      0.018929
# home_ownership_MORTGAGE                                     0.079342
# home_ownership_NONE                                        -0.000492
# home_ownership_OTHER                                       -0.000351
# home_ownership_OWN                                          0.019808
# home_ownership_RENT                                        -0.093408
# desc_length*all_text_length                                -0.007597
# num_actv_rev_tl*num_rev_tl_bal_gt_0                         0.749152
# tot_cur_bal*tot_hi_cred_lim                                 0.076063
# recoveries*collection_recovery_fee                          0.019783
# int_rate*grade                                             -0.031577
# funded_amnt*installment                                     0.137569
# loan_amnt*installment                                       0.137570
# funded_amnt_inv*installment                                 0.137563
# total_bal_ex_mort*total_il_high_credit_limit                0.099256
# pymnt_plan_y*hardship_flag_Y                                0.000531
# revol_util*bc_util                                         -0.167120
# bc_util*percent_bc_gt_75                                   -0.137619
# tot_cur_bal*avg_cur_bal                                    -0.030877
# num_bc_tl*num_rev_accts                                     0.670451
# last_fico_range_high*last_fico_range_low                    0.005637
# open_acc*num_op_rev_tl                                      1.000000
# num_op_rev_tl*num_sats                                      0.999606
# num_actv_bc_tl*num_bc_sats                                  0.674009
# num_actv_bc_tl*num_actv_rev_tl                              0.703615
# avg_cur_bal*tot_hi_cred_lim                                -0.024592
# num_actv_bc_tl*num_rev_tl_bal_gt_0                          0.709241
#
#                                               num_op_rev_tl*num_sats  \
# loan_amnt                                                   0.151353
# funded_amnt                                                 0.151351
# funded_amnt_inv                                             0.151344
# int_rate                                                   -0.000506
# installment                                                 0.146060
# grade                                                      -0.003865
# emp_length                                                  0.078100
# annual_inc                                                  0.093166
# dti                                                         0.172877
# delinq_2yrs                                                 0.016073
# fico_range_low                                              0.025547
# fico_range_high                                             0.025546
# inq_last_6mths                                              0.137247
# open_acc                                                    0.870110
# pub_rec                                                    -0.011707
# revol_bal                                                   0.209748
# revol_util                                                 -0.169271
# total_acc                                                   0.590211
# out_prncp                                                   0.010338
# out_prncp_inv                                               0.010335
# recoveries                                                  0.036837
# ...
# funded_amnt_inv*installment                                     0.165581
# total_bal_ex_mort*total_il_high_credit_limit                    0.039439
# pymnt_plan_y*hardship_flag_Y                                    0.000188
# revol_util*bc_util                                             -0.037667
# bc_util*percent_bc_gt_75                                       -0.079894
# tot_cur_bal*avg_cur_bal                                        -0.012297
# num_bc_tl*num_rev_accts                                         0.591021
# last_fico_range_high*last_fico_range_low                       -0.014745
# open_acc*num_op_rev_tl                                          0.674009
# num_op_rev_tl*num_sats                                          0.671690
# num_actv_bc_tl*num_bc_sats                                      1.000000
# num_actv_bc_tl*num_actv_rev_tl                                  0.917870
# avg_cur_bal*tot_hi_cred_lim                                    -0.007568
# num_actv_bc_tl*num_rev_tl_bal_gt_0                              0.900493
#
#                                               num_actv_bc_tl*num_actv_rev_tl  \
# loan_amnt                                                           0.152968
# funded_amnt                                                         0.152968
# funded_amnt_inv                                                     0.152948
# int_rate                                                            0.052205
# installment                                                         0.158183
# grade                                                              -0.054029
# emp_length                                                          0.092986
# annual_inc                                                          0.087468
# dti                                                                 0.162659
# delinq_2yrs                                                        -0.022593
# fico_range_low                                                     -0.113344
# fico_range_high                                                    -0.113344
# inq_last_6mths                                                      0.097440
# open_acc                                                            0.581662
# pub_rec                                                            -0.021129
# revol_bal                                                           0.281292
# revol_util                                                          0.069183
# total_acc                                                           0.333492
# out_prncp                                                           0.012945
# out_prncp_inv                                                       0.012943
# recoveries                                                          0.043213
# collection_recovery_fee                                             0.043152
# last_pymnt_amnt                                                     0.032958
# last_fico_range_high                                               -0.060488
# last_fico_range_low                                                -0.044585
# collections_12_mths_ex_med                                         -0.000383
# acc_now_delinq                                                     -0.001948
# tot_coll_amt                                                       -0.002606
# tot_cur_bal                                                         0.092841
# acc_open_past_24mths                                                0.264765
# ...                                                                      ...
# addr_state_WV                                                      -0.003999
# addr_state_WY                                                      -0.006540
# disbursement_method_DirectPay                                       0.014068
# debt_settlement_flag_Y                                              0.019783
# home_ownership_MORTGAGE                                             0.047521
# home_ownership_NONE                                                -0.000161
# home_ownership_OTHER                                                0.001446
# home_ownership_OWN                                                  0.007131
# home_ownership_RENT                                                -0.052986
# desc_length*all_text_length                                         0.000098
# num_actv_rev_tl*num_rev_tl_bal_gt_0                                 0.921683
# tot_cur_bal*tot_hi_cred_lim                                         0.055980
# recoveries*collection_recovery_fee                                  0.020071
# int_rate*grade                                                      0.022565
# funded_amnt*installment                                             0.144964
# loan_amnt*installment                                               0.144964
# funded_amnt_inv*installment                                         0.144954
# total_bal_ex_mort*total_il_high_credit_limit                        0.035874
# pymnt_plan_y*hardship_flag_Y                                        0.000866
# revol_util*bc_util                                                  0.042810
# bc_util*percent_bc_gt_75                                            0.009093
# tot_cur_bal*avg_cur_bal                                            -0.024076
# num_bc_tl*num_rev_accts                                             0.522777
# last_fico_range_high*last_fico_range_low                           -0.056023
# open_acc*num_op_rev_tl                                              0.703615
# num_op_rev_tl*num_sats                                              0.701004
# num_actv_bc_tl*num_bc_sats                                          0.917870
# num_actv_bc_tl*num_actv_rev_tl                                      1.000000
# avg_cur_bal*tot_hi_cred_lim                                        -0.020222
# num_actv_bc_tl*num_rev_tl_bal_gt_0                                  0.986857
#
#                                               avg_cur_bal*tot_hi_cred_lim  \
# loan_amnt                                                        0.166044
# funded_amnt                                                      0.166044
# funded_amnt_inv                                                  0.166061
# int_rate                                                        -0.056716
# installment                                                      0.154809
# grade                                                            0.056126
# emp_length                                                       0.042661
# annual_inc                                                       0.302166
# dti                                                             -0.063041
# delinq_2yrs                                                      0.026482
# fico_range_low                                                   0.089510
# fico_range_high                                                  0.089511
# inq_last_6mths                                                  -0.000354
# open_acc                                                        -0.001590
# pub_rec                                                         -0.027640
# revol_bal                                                        0.396486
# revol_util                                                       0.046679
# total_acc                                                        0.064527
# out_prncp                                                        0.003310
# out_prncp_inv                                                    0.003311
# recoveries                                                      -0.003309
# collection_recovery_fee                                         -0.002981
# last_pymnt_amnt                                                  0.121193
# last_fico_range_high                                             0.067619
# last_fico_range_low                                              0.059071
# collections_12_mths_ex_med                                      -0.007542
# acc_now_delinq                                                   0.012453
# tot_coll_amt                                                    -0.000992
# tot_cur_bal                                                      0.692783
# acc_open_past_24mths                                            -0.020090
# ...                                                                   ...
# addr_state_WV                                                   -0.006020
# addr_state_WY                                                   -0.000377
# disbursement_method_DirectPay                                    0.003013
# debt_settlement_flag_Y                                          -0.014262
# home_ownership_MORTGAGE                                          0.206949
# home_ownership_NONE                                             -0.000720
# home_ownership_OTHER                                            -0.000745
# home_ownership_OWN                                              -0.012957
# home_ownership_RENT                                             -0.203366
# desc_length*all_text_length                                     -0.001316
# num_actv_rev_tl*num_rev_tl_bal_gt_0                             -0.030999
# tot_cur_bal*tot_hi_cred_lim                                      0.916744
# recoveries*collection_recovery_fee                               0.006676
# int_rate*grade                                                  -0.051402
# funded_amnt*installment                                          0.169750
# loan_amnt*installment                                            0.169750
# funded_amnt_inv*installment                                      0.169763
# total_bal_ex_mort*total_il_high_credit_limit                     0.205782
# pymnt_plan_y*hardship_flag_Y                                    -0.000075
# revol_util*bc_util                                               0.040912
# bc_util*percent_bc_gt_75                                         0.014916
# tot_cur_bal*avg_cur_bal                                          0.973196
# num_bc_tl*num_rev_accts                                          0.003548
# last_fico_range_high*last_fico_range_low                         0.066724
# open_acc*num_op_rev_tl                                          -0.024592
# num_op_rev_tl*num_sats                                          -0.024671
# num_actv_bc_tl*num_bc_sats                                      -0.007568
# num_actv_bc_tl*num_actv_rev_tl                                  -0.020222
# avg_cur_bal*tot_hi_cred_lim                                      1.000000
# num_actv_bc_tl*num_rev_tl_bal_gt_0                              -0.021519
#
#                                               num_actv_bc_tl*num_rev_tl_bal_gt_0
# loan_amnt                                                               0.153694
# funded_amnt                                                             0.153694
# funded_amnt_inv                                                         0.153673
# int_rate                                                                0.053368
# installment                                                             0.158914
# grade                                                                  -0.055011
# emp_length                                                              0.094831
# annual_inc                                                              0.087221
# dti                                                                     0.166127
# delinq_2yrs                                                            -0.025418
# fico_range_low                                                         -0.115200
# fico_range_high                                                        -0.115200
# inq_last_6mths                                                          0.086463
# open_acc                                                                0.588332
# pub_rec                                                                -0.023790
# revol_bal                                                               0.282825
# revol_util                                                              0.076380
# total_acc                                                               0.336390
# out_prncp                                                               0.011995
# out_prncp_inv                                                           0.011993
# recoveries                                                              0.043377
# collection_recovery_fee                                                 0.043197
# last_pymnt_amnt                                                         0.031305
# last_fico_range_high                                                   -0.061323
# last_fico_range_low                                                    -0.045364
# collections_12_mths_ex_med                                             -0.005184
# acc_now_delinq                                                         -0.002252
# tot_coll_amt                                                           -0.002581
# tot_cur_bal                                                             0.092785
# acc_open_past_24mths                                                    0.262004
# ...                                                                          ...
# addr_state_WV                                                          -0.003820
# addr_state_WY                                                          -0.006473
# disbursement_method_DirectPay                                           0.015510
# debt_settlement_flag_Y                                                  0.019842
# home_ownership_MORTGAGE                                                 0.047175
# home_ownership_NONE                                                    -0.000098
# home_ownership_OTHER                                                    0.001575
# home_ownership_OWN                                                      0.007827
# home_ownership_RENT                                                    -0.053074
# desc_length*all_text_length                                             0.001243
# num_actv_rev_tl*num_rev_tl_bal_gt_0                                     0.929063
# tot_cur_bal*tot_hi_cred_lim                                             0.055122
# recoveries*collection_recovery_fee                                      0.020221
# int_rate*grade                                                          0.023231
# funded_amnt*installment                                                 0.145224
# loan_amnt*installment                                                   0.145224
# funded_amnt_inv*installment                                             0.145214
# total_bal_ex_mort*total_il_high_credit_limit                            0.037116
# pymnt_plan_y*hardship_flag_Y                                            0.000668
# revol_util*bc_util                                                      0.049594
# bc_util*percent_bc_gt_75                                                0.014423
# tot_cur_bal*avg_cur_bal                                                -0.025400
# num_bc_tl*num_rev_accts                                                 0.523269
# last_fico_range_high*last_fico_range_low                               -0.056897
# open_acc*num_op_rev_tl                                                  0.709241
# num_op_rev_tl*num_sats                                                  0.708449
# num_actv_bc_tl*num_bc_sats                                              0.900493
# num_actv_bc_tl*num_actv_rev_tl                                          0.986857
# avg_cur_bal*tot_hi_cred_lim                                            -0.021519
# num_actv_bc_tl*num_rev_tl_bal_gt_0                                      1.000000
#
# [158 rows x 158 columns]

# %%
data.drop(columns= ['funded_amnt', 'funded_amnt_inv'], inplace=True)

# %% [markdown]
# ## With the addition of our engineered columns, the Feature Engineering stage is complete. Next, exporting the polished dataframe as a csv in order to get it into the third and final notebook for Modeling.

# %%
data.to_csv('./cleaned_FEATURES.csv', index=False)
